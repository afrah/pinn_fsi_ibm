# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python -m src.trainer.m2_mlp_trainer
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-20_03-04-45-128256
# GPU memory cleared!
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 300
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 256
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.01
# INFO:src.utils.logger:boundary_weight: 2.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 4.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 2000
# INFO:src.utils.logger:save_every: 4000
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.07
# INFO:src.utils.logger:solid_sampling_ratio: 0.01
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.1
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.15
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cuda
# INFO:src.utils.logger:solver: mlp
# INFO:src.utils.logger:model: m2
# Saved fluid tensor with shape torch.Size([10508, 8]) to ./data/training_dataset/old/fluid_tensor.pt
# Saved fluid_points tensor with shape torch.Size([3986, 8]) to ./data/training_dataset/old/fluid_points_tensor.pt
# Saved interface tensor with shape torch.Size([10166, 11]) to ./data/training_dataset/old/interface_tensor.pt
# Saved solid tensor with shape torch.Size([1452, 8]) to ./data/training_dataset/old/solid_tensor.pt
# Saved left tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/left_tensor.pt
# Saved right tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/right_tensor.pt
# Saved bottom tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/bottom_tensor.pt
# Saved up tensor with shape torch.Size([1545, 8]) to ./data/training_dataset/old/up_tensor.pt
# Saved initial tensor with shape torch.Size([1330, 8]) to ./data/training_dataset/old/initial_tensor.pt
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=300, bias=True)
#     (1-2): 2 x Linear(in_features=300, out_features=300, bias=True)
#     (3): Linear(in_features=300, out_features=3, bias=True)
#   )
# )
# INFO:src.utils.logger:MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=300, bias=True)
#     (1-2): 2 x Linear(in_features=300, out_features=300, bias=True)
#     (3): Linear(in_features=300, out_features=3, bias=True)
#   )
# )
# INFO:src.utils.logger:Number of parameters: 182703
# INFO:src.utils.logger:Epoch 0/60000, Total: 5.2e+00, Data(F): 2.7e-01, Data(S): 1.6e-01, Physics: 2.2e-03, Boundary: 4.7e+00, FSI: 1.2e-02, Solid: 1.8e-01, Initial: 2.6e-01, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 2000/60000, Total: 3.3e-01, Data(F): 2.6e-02, Data(S): 3.3e-02, Physics: 7.8e-03, Boundary: 2.4e-01, FSI: 1.7e-04, Solid: 3.3e-02, Initial: 6.1e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.738e-02 |  Final right: 2.917e-02 |  Final bottom: 1.943e-03 |  Final up: 1.071e-01 |  Final fluid: 2.913e-02 |  Final interface: 2.390e-04 |  Final initial: 2.533e-02 |  Final fluid_total: 2.279e-01 |  Final solid_total: 7.504e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 4000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 4000/60000, Total: 1.6e-01, Data(F): 1.7e-02, Data(S): 1.0e-02, Physics: 3.6e-02, Boundary: 9.9e-02, FSI: 4.3e-04, Solid: 1.0e-02, Initial: 3.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 6000/60000, Total: 1.4e-01, Data(F): 1.2e-02, Data(S): 4.9e-03, Physics: 2.6e-02, Boundary: 9.2e-02, FSI: 5.7e-05, Solid: 5.0e-03, Initial: 7.4e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.944e-03 |  Final right: 7.267e-03 |  Final bottom: 3.500e-04 |  Final up: 3.510e-02 |  Final fluid: 1.067e-02 |  Final interface: 2.725e-05 |  Final initial: 1.966e-03 |  Final fluid_total: 6.972e-02 |  Final solid_total: 7.783e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 8000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 8000/60000, Total: 1.0e-01, Data(F): 1.1e-02, Data(S): 3.8e-03, Physics: 1.7e-02, Boundary: 7.1e-02, FSI: 2.8e-05, Solid: 3.9e-03, Initial: 2.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 10000/60000, Total: 3.8e-01, Data(F): 1.1e-02, Data(S): 4.8e-03, Physics: 4.0e-02, Boundary: 3.2e-01, FSI: 3.0e-05, Solid: 4.8e-03, Initial: 4.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 5.353e-03 |  Final right: 3.378e-03 |  Final bottom: 9.025e-04 |  Final up: 1.557e-02 |  Final fluid: 2.522e-02 |  Final interface: 1.454e-05 |  Final initial: 2.514e-03 |  Final fluid_total: 6.344e-02 |  Final solid_total: 3.700e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 12000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 12000/60000, Total: 8.4e-02, Data(F): 1.5e-02, Data(S): 1.1e-02, Physics: 2.3e-02, Boundary: 4.3e-02, FSI: 3.7e-05, Solid: 1.1e-02, Initial: 4.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 14000/60000, Total: 1.7e-01, Data(F): 9.0e-03, Data(S): 5.0e-03, Physics: 1.3e-02, Boundary: 1.3e-01, FSI: 3.1e-05, Solid: 5.1e-03, Initial: 1.9e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.120e-02 |  Final right: 2.734e-03 |  Final bottom: 4.678e-04 |  Final up: 2.173e-02 |  Final fluid: 2.094e-02 |  Final interface: 8.687e-05 |  Final initial: 1.088e-03 |  Final fluid_total: 6.595e-02 |  Final solid_total: 3.994e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 16000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 16000/60000, Total: 4.6e-02, Data(F): 8.7e-03, Data(S): 2.5e-03, Physics: 9.5e-03, Boundary: 2.5e-02, FSI: 4.1e-05, Solid: 2.5e-03, Initial: 2.4e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 18000/60000, Total: 5.2e-02, Data(F): 5.9e-03, Data(S): 3.5e-03, Physics: 1.3e-02, Boundary: 2.4e-02, FSI: 2.2e-05, Solid: 3.5e-03, Initial: 9.6e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.424e-02 |  Final right: 8.511e-03 |  Final bottom: 1.392e-03 |  Final up: 1.360e-02 |  Final fluid: 1.785e-02 |  Final interface: 6.069e-05 |  Final initial: 5.622e-03 |  Final fluid_total: 6.972e-02 |  Final solid_total: 3.903e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 20000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 20000/60000, Total: 4.8e-02, Data(F): 7.8e-03, Data(S): 2.8e-03, Physics: 1.3e-02, Boundary: 2.0e-02, FSI: 2.9e-05, Solid: 2.8e-03, Initial: 7.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 22000/60000, Total: 8.6e-02, Data(F): 8.4e-03, Data(S): 6.6e-03, Physics: 1.9e-02, Boundary: 5.4e-02, FSI: 3.2e-05, Solid: 6.6e-03, Initial: 3.3e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.669e-03 |  Final right: 4.864e-03 |  Final bottom: 1.317e-03 |  Final up: 8.333e-03 |  Final fluid: 1.334e-02 |  Final interface: 2.068e-05 |  Final initial: 5.263e-03 |  Final fluid_total: 4.141e-02 |  Final solid_total: 4.025e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 24000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 24000/60000, Total: 5.5e-02, Data(F): 6.3e-03, Data(S): 5.1e-03, Physics: 8.9e-03, Boundary: 3.4e-02, FSI: 1.7e-05, Solid: 5.2e-03, Initial: 5.9e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 26000/60000, Total: 5.0e-02, Data(F): 6.5e-03, Data(S): 2.6e-03, Physics: 2.6e-02, Boundary: 1.4e-02, FSI: 9.5e-06, Solid: 2.6e-03, Initial: 3.0e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.501e-03 |  Final right: 3.477e-03 |  Final bottom: 3.274e-04 |  Final up: 4.715e-03 |  Final fluid: 1.521e-02 |  Final interface: 5.229e-05 |  Final initial: 1.536e-03 |  Final fluid_total: 3.420e-02 |  Final solid_total: 2.935e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 28000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 28000/60000, Total: 5.2e-02, Data(F): 7.0e-03, Data(S): 3.8e-03, Physics: 1.4e-02, Boundary: 2.7e-02, FSI: 3.1e-05, Solid: 3.8e-03, Initial: 3.6e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 30000/60000, Total: 2.7e-02, Data(F): 5.5e-03, Data(S): 4.1e-03, Physics: 7.1e-03, Boundary: 1.3e-02, FSI: 2.2e-05, Solid: 4.2e-03, Initial: 1.1e-03, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 8.443e-03 |  Final right: 2.771e-03 |  Final bottom: 7.484e-04 |  Final up: 1.468e-02 |  Final fluid: 1.985e-02 |  Final interface: 1.804e-05 |  Final initial: 3.474e-03 |  Final fluid_total: 5.758e-02 |  Final solid_total: 3.327e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 32000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 32000/60000, Total: 5.7e-02, Data(F): 8.4e-03, Data(S): 3.2e-03, Physics: 2.0e-02, Boundary: 2.5e-02, FSI: 2.4e-05, Solid: 3.2e-03, Initial: 3.6e-03, LR: 8.50e-04
# INFO:src.utils.logger:Epoch 34000/60000, Total: 6.3e-02, Data(F): 9.1e-03, Data(S): 2.1e-03, Physics: 1.9e-02, Boundary: 3.1e-02, FSI: 3.0e-05, Solid: 2.1e-03, Initial: 4.2e-03, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.038e-03 |  Final right: 8.874e-03 |  Final bottom: 4.483e-04 |  Final up: 1.230e-02 |  Final fluid: 1.362e-02 |  Final interface: 2.370e-05 |  Final initial: 1.391e-02 |  Final fluid_total: 5.963e-02 |  Final solid_total: 4.107e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 36000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 36000/60000, Total: 2.9e-02, Data(F): 5.9e-03, Data(S): 4.6e-03, Physics: 1.1e-02, Boundary: 1.2e-02, FSI: 2.9e-05, Solid: 4.6e-03, Initial: 8.1e-04, LR: 8.50e-04
# INFO:src.utils.logger:Epoch 38000/60000, Total: 3.6e-02, Data(F): 6.1e-03, Data(S): 4.4e-03, Physics: 6.9e-03, Boundary: 2.2e-02, FSI: 2.0e-05, Solid: 4.5e-03, Initial: 1.3e-03, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.435e-03 |  Final right: 1.448e-03 |  Final bottom: 2.268e-04 |  Final up: 1.136e-02 |  Final fluid: 7.462e-03 |  Final interface: 3.223e-05 |  Final initial: 7.665e-04 |  Final fluid_total: 2.935e-02 |  Final solid_total: 3.000e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 40000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 40000/60000, Total: 3.4e-02, Data(F): 6.6e-03, Data(S): 3.5e-03, Physics: 1.4e-02, Boundary: 1.3e-02, FSI: 6.1e-05, Solid: 3.5e-03, Initial: 9.4e-04, LR: 7.22e-04
# INFO:src.utils.logger:Epoch 42000/60000, Total: 3.1e-02, Data(F): 5.4e-03, Data(S): 3.1e-03, Physics: 1.1e-02, Boundary: 1.4e-02, FSI: 5.1e-05, Solid: 3.2e-03, Initial: 1.1e-03, LR: 7.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.645e-03 |  Final right: 4.434e-03 |  Final bottom: 1.712e-03 |  Final up: 7.031e-03 |  Final fluid: 1.433e-02 |  Final interface: 1.949e-05 |  Final initial: 3.359e-03 |  Final fluid_total: 4.269e-02 |  Final solid_total: 3.734e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 44000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 44000/60000, Total: 4.7e-02, Data(F): 1.1e-02, Data(S): 2.7e-03, Physics: 1.2e-02, Boundary: 2.2e-02, FSI: 2.8e-05, Solid: 2.7e-03, Initial: 9.7e-04, LR: 7.22e-04
# INFO:src.utils.logger:Epoch 46000/60000, Total: 2.9e-02, Data(F): 4.3e-03, Data(S): 3.1e-03, Physics: 1.0e-02, Boundary: 1.4e-02, FSI: 7.4e-06, Solid: 3.1e-03, Initial: 8.0e-04, LR: 7.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.393e-03 |  Final right: 4.583e-03 |  Final bottom: 3.012e-04 |  Final up: 4.640e-03 |  Final fluid: 1.212e-02 |  Final interface: 7.945e-06 |  Final initial: 9.132e-04 |  Final fluid_total: 2.939e-02 |  Final solid_total: 4.483e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 48000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 48000/60000, Total: 4.1e-02, Data(F): 5.8e-03, Data(S): 3.9e-03, Physics: 1.3e-02, Boundary: 2.0e-02, FSI: 2.3e-05, Solid: 4.0e-03, Initial: 1.5e-03, LR: 7.22e-04
# INFO:src.utils.logger:Epoch 50000/60000, Total: 3.1e-02, Data(F): 6.1e-03, Data(S): 4.8e-03, Physics: 9.8e-03, Boundary: 1.4e-02, FSI: 3.3e-06, Solid: 4.8e-03, Initial: 6.9e-04, LR: 6.14e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 4.722e-03 |  Final right: 2.324e-03 |  Final bottom: 1.817e-04 |  Final up: 6.306e-03 |  Final fluid: 7.903e-03 |  Final interface: 1.556e-05 |  Final initial: 1.053e-03 |  Final fluid_total: 2.783e-02 |  Final solid_total: 3.705e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 52000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 52000/60000, Total: 2.6e-02, Data(F): 6.6e-03, Data(S): 3.1e-03, Physics: 8.6e-03, Boundary: 8.8e-03, FSI: 6.4e-06, Solid: 3.1e-03, Initial: 2.4e-03, LR: 6.14e-04
# INFO:src.utils.logger:Epoch 54000/60000, Total: 7.2e-02, Data(F): 6.0e-03, Data(S): 4.5e-03, Physics: 4.7e-02, Boundary: 1.6e-02, FSI: 4.0e-05, Solid: 4.6e-03, Initial: 2.5e-03, LR: 6.14e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 5.130e-03 |  Final right: 9.974e-03 |  Final bottom: 3.090e-04 |  Final up: 2.288e-02 |  Final fluid: 1.403e-02 |  Final interface: 1.136e-05 |  Final initial: 2.701e-03 |  Final fluid_total: 6.105e-02 |  Final solid_total: 3.656e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 56000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Epoch 56000/60000, Total: 2.4e-02, Data(F): 5.7e-03, Data(S): 5.2e-03, Physics: 6.9e-03, Boundary: 9.5e-03, FSI: 2.7e-05, Solid: 5.3e-03, Initial: 1.7e-03, LR: 6.14e-04
# INFO:src.utils.logger:Epoch 58000/60000, Total: 3.7e-02, Data(F): 7.0e-03, Data(S): 4.4e-03, Physics: 6.2e-03, Boundary: 1.8e-02, FSI: 7.2e-06, Solid: 4.4e-03, Initial: 5.6e-03, LR: 6.14e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 9.656e-04 |  Final right: 1.844e-03 |  Final bottom: 3.216e-04 |  Final up: 4.312e-03 |  Final fluid: 1.840e-02 |  Final interface: 1.695e-05 |  Final initial: 1.225e-03 |  Final fluid_total: 3.161e-02 |  Final solid_total: 3.444e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 60000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 9.656e-04 |  Final right: 1.844e-03 |  Final bottom: 3.216e-04 |  Final up: 4.312e-03 |  Final fluid: 1.840e-02 |  Final interface: 1.695e-05 |  Final initial: 1.225e-03 |  Final fluid_total: 3.161e-02 |  Final solid_total: 3.444e-03 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 60000 | Training checkpoint saved at ./checkpoints/2025-08-20_03-04-45-128256/model.pth
# INFO:src.utils.logger:Number of parameters: 182703
# final loss BC: 7.44e-03
# Warning: Loss history for Data is empty.
# Warning: Loss history for Fluid points is empty.
# final loss Physics: 1.84e-02
# final loss FSI: 1.70e-05
# final loss Initial: 1.22e-03
# /home/afrah/ubuntu/afrah/code/pinn_fsi_ibm/src/utils/plot_losses.py:139: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(bottom=y_min)
# Figure(1200x800)
# INFO:src.utils.logger:Relative L2 error for u: 1.64e+01 %
# INFO:src.utils.logger:Relative L2 error for v: 3.14e+01 %
# INFO:src.utils.logger:Relative L2 error for p: 2.71e+01 %
# INFO:src.utils.logger:On the interface
# INFO:src.utils.logger:Relative L2 error for u: 2.03e+01 %
# INFO:src.utils.logger:Relative L2 error for v: 2.89e+01 %
# INFO:src.utils.logger:Relative L2 error for p: 2.87e+01 %
# Figure(3000x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)

# %%
import torch
from src.utils.utils import lp_error
from src.utils.logger import Logging
from src.utils.colors import model_color

from src.nn.tanh import MLP
from src.nn.bspline import KAN
from src.utils.utils import clear_gpu_memory
from src.data.IBM_data_loader import prepare_training_data, visualize_tensor_datasets
from src.data.IBM_data_loader import load_fluid_testing_dataset
from src.models.m2_physics import PINNTrainer
from src.utils.plot_losses import plot_M1_loss_history
from src.utils.fsi_visualization import (
    create_frames,
    create_animations_from_existing_frames,
)
from src.data.IBM_data_loader import load_training_dataset

# %%
CHECKPOINT_PATH = "./checkpoints"
logger = Logging(CHECKPOINT_PATH)
model_dirname = logger.get_output_dir()

logger.print(model_dirname)
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-20_13-59-43-146571

# %%
clear_gpu_memory()
config = {
    "dataset_type": "old",
    "training_selection_method": "Sobol",
    "input_dim": 3,  # (x, y, z, t)
    "hidden_dim": 100,
    "hidden_layers_dim": 3,
    "fluid_density": 1.0,
    "fluid_viscosity": 0.01,
    "num_epochs": 60000,
    "batch_size": 128,
    "learning_rate": 1e-3,
    "data_weight": 2.0,
    "physics_weight": 0.01,
    "boundary_weight": 2.0,
    "fsi_weight": 0.5,
    "initial_weight": 4.0,
    "checkpoint_dir": "./checkpoints",
    "resume": None,
    "print_every": 10,
    "save_every": 20,
    "fluid_sampling_ratio": 0.01,
    "interface_sampling_ratio": 0.07,
    "solid_sampling_ratio": 0.07,
    "left_sampling_ratio": 0.1,
    "right_sampling_ratio": 0.15,
    "bottom_sampling_ratio": 0.1,
    "top_sampling_ratio": 0.1,
    "initial_sampling_ratio": 0.1,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    "solver": "kan",
    "model": "m2",
}
# Out:
# GPU memory cleared!

# %%
training_data["interface"][: , 0:1].min()
# Out:
# tensor(0., device='cuda:0')

# %%
logger.print("Config:")
for key, value in config.items():
    logger.print(f"{key}: {value}")

training_data_path = "./data/training_dataset/old"

training_data = None #load_training_dataset(training_data_path, device=config["device"])

if training_data is None:
    training_data = prepare_training_data(
        config["dataset_type"],
        fluid_sampling_ratio=config["fluid_sampling_ratio"],
        interface_sampling_ratio=config["interface_sampling_ratio"],
        solid_sampling_ratio=config["solid_sampling_ratio"],
        left_sampling_ratio=config["left_sampling_ratio"],
        right_sampling_ratio=config["right_sampling_ratio"],
        bottom_sampling_ratio=config["bottom_sampling_ratio"],
        top_sampling_ratio=config["top_sampling_ratio"],
        initial_sampling_ratio=config["initial_sampling_ratio"],
        training_selection_method=config["training_selection_method"],
        device=config["device"],
        save_dir=training_data_path,
    )
# Out:
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 100
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 128
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.01
# INFO:src.utils.logger:boundary_weight: 2.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 4.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 10
# INFO:src.utils.logger:save_every: 20
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.07
# INFO:src.utils.logger:solid_sampling_ratio: 0.07
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.15
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.1
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cuda
# INFO:src.utils.logger:solver: kan
# INFO:src.utils.logger:model: m2
# Saved fluid tensor with shape torch.Size([10508, 8]) to ./data/training_dataset/old/fluid_tensor.pt
# Saved fluid_points tensor with shape torch.Size([3986, 8]) to ./data/training_dataset/old/fluid_points_tensor.pt
# Saved interface tensor with shape torch.Size([10166, 11]) to ./data/training_dataset/old/interface_tensor.pt
# Saved solid tensor with shape torch.Size([10166, 8]) to ./data/training_dataset/old/solid_tensor.pt
# Saved left tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/left_tensor.pt
# Saved right tensor with shape torch.Size([1545, 8]) to ./data/training_dataset/old/right_tensor.pt
# Saved bottom tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/bottom_tensor.pt
# Saved up tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/up_tensor.pt
# Saved initial tensor with shape torch.Size([1330, 8]) to ./data/training_dataset/old/initial_tensor.pt

# %%
visualize_tensor_datasets(training_data, save_dir=training_data_path)

fluid_network = (
    [config["input_dim"]] + [config["hidden_dim"]] * config["hidden_layers_dim"] + [3]
)
if config["solver"] == "mlp":
    fluid_model = MLP(network=fluid_network)
    solid_model = MLP(network=fluid_network)
else:
    fluid_model = KAN(fluid_network)
    solid_model = KAN(fluid_network)

logger.print("Fluid model architecture:")
logger.print(fluid_model)
logger.print(solid_model)
logger.print(
    f"Number of parameters: {sum(p.numel() for p in fluid_model.parameters())}"
)
# Out:
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:KAN(
#   (layers): ModuleList(
#     (0-3): 4 x KANLinear(
#       (base_activation): SiLU()
#     )
#   )
# )
# INFO:src.utils.logger:KAN(
#   (layers): ModuleList(
#     (0-3): 4 x KANLinear(
#       (base_activation): SiLU()
#     )
#   )
# )
# INFO:src.utils.logger:Number of parameters: 206000

# %%
trainer = PINNTrainer(
    fluid_model=fluid_model,
    solid_model=solid_model,
    training_data=training_data,
    learning_rate=config["learning_rate"],
    logger=logger,
    device=config["device"],
    fluid_density=config["fluid_density"],
    fluid_viscosity=config["fluid_viscosity"],
    print_every=config["print_every"],
    save_every=config["save_every"],
    solver=config["solver"],
    model=config["model"],
)


loss_history = trainer.train(
    num_epochs=config["num_epochs"],
    batch_size=config["batch_size"],
    data_weight=config["data_weight"],
    physics_weight=config["physics_weight"],
    boundary_weight=config["boundary_weight"],
    fsi_weight=config["fsi_weight"],
    initial_weight=config["initial_weight"],
)
