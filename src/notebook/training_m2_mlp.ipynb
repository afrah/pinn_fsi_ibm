# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python -m src.trainer.m2_mlp_trainer
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-21_00-00-32-840132
# GPU memory cleared!
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 400
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 256
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.005
# INFO:src.utils.logger:boundary_weight: 4.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 0.5
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 1000
# INFO:src.utils.logger:save_every: 2000
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.05
# INFO:src.utils.logger:solid_sampling_ratio: 0.01
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.1
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.15
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cuda
# INFO:src.utils.logger:solver: mlp
# INFO:src.utils.logger:model: m2
# Saved fluid tensor with shape torch.Size([10508, 8]) to ./data/training_dataset/old/fluid_tensor.pt
# Saved fluid_points tensor with shape torch.Size([3986, 8]) to ./data/training_dataset/old/fluid_points_tensor.pt
# Saved interface tensor with shape torch.Size([7262, 11]) to ./data/training_dataset/old/interface_tensor.pt
# Saved solid tensor with shape torch.Size([1452, 8]) to ./data/training_dataset/old/solid_tensor.pt
# Saved left tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/left_tensor.pt
# Saved right tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/right_tensor.pt
# Saved bottom tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/bottom_tensor.pt
# Saved up tensor with shape torch.Size([1545, 8]) to ./data/training_dataset/old/up_tensor.pt
# Saved initial tensor with shape torch.Size([1330, 8]) to ./data/training_dataset/old/initial_tensor.pt
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=400, bias=True)
#     (1-2): 2 x Linear(in_features=400, out_features=400, bias=True)
#     (3): Linear(in_features=400, out_features=3, bias=True)
#   )
# )
# INFO:src.utils.logger:MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=50, bias=True)
#     (1-2): 2 x Linear(in_features=50, out_features=50, bias=True)
#     (3): Linear(in_features=50, out_features=3, bias=True)
#   )
# )
# INFO:src.utils.logger:Number of parameters: 323603
# INFO:src.utils.logger:Epoch 0/60000, Total: 5.7e+00, Data(F): 1.5e-01, Data(S): 1.3e-01, Physics: 3.0e-04, Boundary: 5.5e+00, FSI: 4.2e-02, Solid: 1.7e-01, Initial: 1.7e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1000/60000, Total: 2.9e-01, Data(F): 5.7e-02, Data(S): 2.8e-02, Physics: 1.3e-03, Boundary: 2.1e-01, FSI: 6.1e-03, Solid: 3.4e-02, Initial: 1.2e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.236e-02 |  Final right: 2.400e-02 |  Final bottom: 2.964e-03 |  Final up: 5.658e-02 |  Final solid: 2.641e-02 |  Final fluid_points: 3.656e-02 |  Final fluid: 3.223e-03 |  Final interface: 4.733e-03 |  Final initial: 7.662e-03 |  Final fluid_total: 1.481e-01 |  Final solid_total: 3.114e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 2000/60000, Total: 1.6e-01, Data(F): 3.0e-02, Data(S): 3.9e-02, Physics: 4.1e-03, Boundary: 1.1e-01, FSI: 5.4e-03, Solid: 4.5e-02, Initial: 6.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 3000/60000, Total: 1.4e-01, Data(F): 3.7e-02, Data(S): 3.2e-02, Physics: 6.9e-03, Boundary: 8.5e-02, FSI: 6.1e-03, Solid: 3.8e-02, Initial: 4.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.554e-02 |  Final right: 1.250e-02 |  Final bottom: 1.586e-03 |  Final up: 6.376e-02 |  Final solid: 2.132e-02 |  Final fluid_points: 2.232e-02 |  Final fluid: 6.619e-03 |  Final interface: 5.253e-03 |  Final initial: 7.004e-03 |  Final fluid_total: 1.546e-01 |  Final solid_total: 2.657e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 4000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 4000/60000, Total: 1.5e-01, Data(F): 2.6e-02, Data(S): 2.0e-02, Physics: 8.3e-03, Boundary: 1.1e-01, FSI: 6.4e-03, Solid: 2.6e-02, Initial: 3.4e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 5000/60000, Total: 1.1e-01, Data(F): 3.0e-02, Data(S): 2.6e-02, Physics: 4.6e-03, Boundary: 6.4e-02, FSI: 5.8e-03, Solid: 3.2e-02, Initial: 2.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 5.247e-03 |  Final right: 9.216e-03 |  Final bottom: 3.128e-04 |  Final up: 2.726e-02 |  Final solid: 2.329e-02 |  Final fluid_points: 2.464e-02 |  Final fluid: 7.347e-03 |  Final interface: 6.708e-03 |  Final initial: 1.976e-03 |  Final fluid_total: 8.271e-02 |  Final solid_total: 3.000e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 6000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 6000/60000, Total: 1.2e-01, Data(F): 4.4e-02, Data(S): 2.4e-02, Physics: 5.2e-03, Boundary: 6.0e-02, FSI: 5.6e-03, Solid: 2.9e-02, Initial: 1.8e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 7000/60000, Total: 6.8e-02, Data(F): 1.9e-02, Data(S): 2.4e-02, Physics: 1.7e-02, Boundary: 2.5e-02, FSI: 5.6e-03, Solid: 2.9e-02, Initial: 1.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.028e-02 |  Final right: 7.378e-03 |  Final bottom: 4.724e-04 |  Final up: 2.102e-02 |  Final solid: 2.753e-02 |  Final fluid_points: 1.135e-02 |  Final fluid: 4.119e-03 |  Final interface: 5.376e-03 |  Final initial: 1.120e-03 |  Final fluid_total: 6.112e-02 |  Final solid_total: 3.291e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 8000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 8000/60000, Total: 8.3e-02, Data(F): 1.5e-02, Data(S): 2.0e-02, Physics: 3.3e-03, Boundary: 5.7e-02, FSI: 4.8e-03, Solid: 2.5e-02, Initial: 2.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 9000/60000, Total: 7.6e-02, Data(F): 1.4e-02, Data(S): 2.6e-02, Physics: 1.7e-02, Boundary: 3.6e-02, FSI: 6.4e-03, Solid: 3.3e-02, Initial: 1.3e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.169e-02 |  Final right: 4.504e-03 |  Final bottom: 9.126e-05 |  Final up: 1.436e-02 |  Final solid: 2.479e-02 |  Final fluid_points: 1.140e-02 |  Final fluid: 7.062e-03 |  Final interface: 4.709e-03 |  Final initial: 1.114e-03 |  Final fluid_total: 5.493e-02 |  Final solid_total: 2.950e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 10000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 10000/60000, Total: 6.2e-02, Data(F): 1.2e-02, Data(S): 3.9e-02, Physics: 5.1e-03, Boundary: 3.8e-02, FSI: 3.8e-03, Solid: 4.3e-02, Initial: 2.3e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 11000/60000, Total: 6.6e-02, Data(F): 1.2e-02, Data(S): 1.9e-02, Physics: 2.3e-02, Boundary: 2.4e-02, FSI: 6.1e-03, Solid: 2.5e-02, Initial: 1.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.980e-03 |  Final right: 9.298e-03 |  Final bottom: 1.864e-03 |  Final up: 9.821e-03 |  Final solid: 3.644e-02 |  Final fluid_points: 9.195e-03 |  Final fluid: 1.060e-02 |  Final interface: 4.653e-03 |  Final initial: 2.320e-03 |  Final fluid_total: 5.173e-02 |  Final solid_total: 4.109e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 12000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 12000/60000, Total: 4.2e-02, Data(F): 1.6e-02, Data(S): 2.6e-02, Physics: 4.1e-03, Boundary: 1.5e-02, FSI: 4.3e-03, Solid: 3.0e-02, Initial: 1.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 13000/60000, Total: 5.7e-02, Data(F): 1.3e-02, Data(S): 3.1e-02, Physics: 6.2e-03, Boundary: 3.1e-02, FSI: 5.5e-03, Solid: 3.7e-02, Initial: 1.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 4.808e-03 |  Final right: 3.547e-03 |  Final bottom: 3.880e-04 |  Final up: 3.714e-03 |  Final solid: 2.062e-02 |  Final fluid_points: 2.153e-02 |  Final fluid: 6.877e-03 |  Final interface: 5.301e-03 |  Final initial: 7.599e-04 |  Final fluid_total: 4.693e-02 |  Final solid_total: 2.592e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 14000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 14000/60000, Total: 4.7e-02, Data(F): 1.7e-02, Data(S): 2.4e-02, Physics: 6.3e-03, Boundary: 1.8e-02, FSI: 5.1e-03, Solid: 2.9e-02, Initial: 5.5e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 15000/60000, Total: 4.7e-02, Data(F): 8.8e-03, Data(S): 2.2e-02, Physics: 1.3e-02, Boundary: 2.0e-02, FSI: 4.7e-03, Solid: 2.7e-02, Initial: 1.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.713e-03 |  Final right: 3.127e-03 |  Final bottom: 1.246e-04 |  Final up: 9.871e-03 |  Final solid: 3.847e-02 |  Final fluid_points: 1.051e-02 |  Final fluid: 5.328e-03 |  Final interface: 6.075e-03 |  Final initial: 6.882e-04 |  Final fluid_total: 3.844e-02 |  Final solid_total: 4.454e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 16000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 16000/60000, Total: 4.9e-02, Data(F): 1.3e-02, Data(S): 2.1e-02, Physics: 7.9e-03, Boundary: 2.2e-02, FSI: 5.8e-03, Solid: 2.7e-02, Initial: 1.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 17000/60000, Total: 4.6e-02, Data(F): 1.0e-02, Data(S): 2.5e-02, Physics: 8.7e-03, Boundary: 2.1e-02, FSI: 5.3e-03, Solid: 3.0e-02, Initial: 9.1e-04, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 4.222e-03 |  Final right: 4.906e-03 |  Final bottom: 7.440e-05 |  Final up: 2.068e-03 |  Final solid: 3.085e-02 |  Final fluid_points: 1.053e-02 |  Final fluid: 2.696e-03 |  Final interface: 6.498e-03 |  Final initial: 5.969e-04 |  Final fluid_total: 3.159e-02 |  Final solid_total: 3.734e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 18000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 18000/60000, Total: 3.6e-02, Data(F): 7.9e-03, Data(S): 2.9e-02, Physics: 5.8e-03, Boundary: 1.8e-02, FSI: 4.4e-03, Solid: 3.4e-02, Initial: 4.8e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 19000/60000, Total: 4.1e-02, Data(F): 1.5e-02, Data(S): 1.9e-02, Physics: 5.1e-03, Boundary: 1.6e-02, FSI: 4.8e-03, Solid: 2.4e-02, Initial: 3.4e-04, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.374e-03 |  Final right: 2.355e-03 |  Final bottom: 3.098e-04 |  Final up: 8.413e-03 |  Final solid: 1.997e-02 |  Final fluid_points: 1.182e-02 |  Final fluid: 1.948e-02 |  Final interface: 5.336e-03 |  Final initial: 1.398e-03 |  Final fluid_total: 5.248e-02 |  Final solid_total: 2.530e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 20000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 20000/60000, Total: 3.9e-02, Data(F): 7.7e-03, Data(S): 3.7e-02, Physics: 1.1e-02, Boundary: 1.4e-02, FSI: 5.8e-03, Solid: 4.3e-02, Initial: 1.1e-03, LR: 8.50e-04
# INFO:src.utils.logger:Epoch 21000/60000, Total: 3.6e-02, Data(F): 7.2e-03, Data(S): 2.3e-02, Physics: 5.9e-03, Boundary: 1.7e-02, FSI: 4.9e-03, Solid: 2.8e-02, Initial: 6.9e-04, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 4.178e-04 |  Final right: 4.469e-03 |  Final bottom: 4.161e-04 |  Final up: 6.959e-03 |  Final solid: 2.403e-02 |  Final fluid_points: 6.792e-03 |  Final fluid: 5.383e-03 |  Final interface: 3.967e-03 |  Final initial: 4.998e-04 |  Final fluid_total: 2.890e-02 |  Final solid_total: 2.800e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 22000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 22000/60000, Total: 4.4e-02, Data(F): 1.4e-02, Data(S): 3.2e-02, Physics: 9.8e-03, Boundary: 1.4e-02, FSI: 4.8e-03, Solid: 3.6e-02, Initial: 8.5e-04, LR: 8.50e-04
# INFO:src.utils.logger:Epoch 23000/60000, Total: 4.7e-02, Data(F): 1.3e-02, Data(S): 2.2e-02, Physics: 7.5e-03, Boundary: 2.0e-02, FSI: 4.9e-03, Solid: 2.7e-02, Initial: 6.7e-04, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.933e-03 |  Final right: 2.994e-03 |  Final bottom: 1.220e-04 |  Final up: 1.304e-02 |  Final solid: 2.549e-02 |  Final fluid_points: 7.583e-03 |  Final fluid: 5.909e-03 |  Final interface: 5.051e-03 |  Final initial: 8.906e-04 |  Final fluid_total: 3.752e-02 |  Final solid_total: 3.054e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 24000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 24000/60000, Total: 4.1e-02, Data(F): 1.0e-02, Data(S): 1.5e-02, Physics: 4.2e-03, Boundary: 2.0e-02, FSI: 5.9e-03, Solid: 2.1e-02, Initial: 1.7e-03, LR: 8.50e-04
# INFO:src.utils.logger:Epoch 25000/60000, Total: 6.8e-02, Data(F): 1.4e-02, Data(S): 1.9e-02, Physics: 3.0e-03, Boundary: 4.5e-02, FSI: 5.1e-03, Solid: 2.5e-02, Initial: 9.2e-04, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 4.859e-03 |  Final right: 3.392e-03 |  Final bottom: 7.826e-05 |  Final up: 3.396e-03 |  Final solid: 3.641e-02 |  Final fluid_points: 5.664e-03 |  Final fluid: 7.537e-03 |  Final interface: 5.535e-03 |  Final initial: 4.334e-04 |  Final fluid_total: 3.089e-02 |  Final solid_total: 4.194e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 26000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 26000/60000, Total: 3.3e-02, Data(F): 1.1e-02, Data(S): 1.4e-02, Physics: 4.5e-03, Boundary: 1.0e-02, FSI: 5.8e-03, Solid: 2.0e-02, Initial: 8.2e-04, LR: 8.50e-04
# INFO:src.utils.logger:Epoch 27000/60000, Total: 4.3e-02, Data(F): 1.6e-02, Data(S): 2.0e-02, Physics: 5.6e-03, Boundary: 1.6e-02, FSI: 5.1e-03, Solid: 2.5e-02, Initial: 4.9e-04, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.749e-03 |  Final right: 1.105e-03 |  Final bottom: 2.090e-04 |  Final up: 7.321e-03 |  Final solid: 3.642e-02 |  Final fluid_points: 1.353e-02 |  Final fluid: 6.733e-03 |  Final interface: 6.500e-03 |  Final initial: 1.057e-03 |  Final fluid_total: 3.920e-02 |  Final solid_total: 4.292e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 28000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 28000/60000, Total: 3.1e-02, Data(F): 6.3e-03, Data(S): 2.0e-02, Physics: 7.9e-03, Boundary: 1.0e-02, FSI: 5.2e-03, Solid: 2.5e-02, Initial: 9.2e-04, LR: 8.50e-04
# INFO:src.utils.logger:Epoch 29000/60000, Total: 3.3e-02, Data(F): 8.2e-03, Data(S): 1.8e-02, Physics: 4.4e-03, Boundary: 1.5e-02, FSI: 6.0e-03, Solid: 2.4e-02, Initial: 3.2e-04, LR: 7.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.791e-03 |  Final right: 3.985e-03 |  Final bottom: 1.168e-03 |  Final up: 7.242e-03 |  Final solid: 1.639e-02 |  Final fluid_points: 7.451e-03 |  Final fluid: 1.782e-02 |  Final interface: 5.583e-03 |  Final initial: 7.091e-04 |  Final fluid_total: 4.775e-02 |  Final solid_total: 2.197e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 30000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 30000/60000, Total: 4.0e-02, Data(F): 8.3e-03, Data(S): 1.7e-02, Physics: 6.6e-03, Boundary: 1.7e-02, FSI: 6.7e-03, Solid: 2.4e-02, Initial: 6.6e-04, LR: 7.22e-04
# INFO:src.utils.logger:Epoch 31000/60000, Total: 3.6e-02, Data(F): 5.2e-03, Data(S): 1.9e-02, Physics: 9.5e-03, Boundary: 1.5e-02, FSI: 5.9e-03, Solid: 2.5e-02, Initial: 6.7e-04, LR: 7.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.304e-03 |  Final right: 1.642e-03 |  Final bottom: 1.032e-04 |  Final up: 9.936e-03 |  Final solid: 2.221e-02 |  Final fluid_points: 1.376e-02 |  Final fluid: 8.479e-03 |  Final interface: 5.299e-03 |  Final initial: 1.134e-03 |  Final fluid_total: 4.265e-02 |  Final solid_total: 2.751e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 32000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 32000/60000, Total: 3.5e-02, Data(F): 1.4e-02, Data(S): 1.7e-02, Physics: 5.8e-03, Boundary: 9.7e-03, FSI: 5.1e-03, Solid: 2.2e-02, Initial: 9.0e-04, LR: 7.22e-04
# INFO:src.utils.logger:Epoch 33000/60000, Total: 3.7e-02, Data(F): 1.1e-02, Data(S): 1.9e-02, Physics: 6.1e-03, Boundary: 1.2e-02, FSI: 6.6e-03, Solid: 2.5e-02, Initial: 9.9e-04, LR: 7.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.300e-03 |  Final right: 1.421e-03 |  Final bottom: 1.086e-04 |  Final up: 5.866e-03 |  Final solid: 2.008e-02 |  Final fluid_points: 8.887e-03 |  Final fluid: 9.025e-03 |  Final interface: 5.563e-03 |  Final initial: 3.864e-04 |  Final fluid_total: 3.356e-02 |  Final solid_total: 2.564e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 34000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 34000/60000, Total: 2.8e-02, Data(F): 8.2e-03, Data(S): 2.3e-02, Physics: 4.2e-03, Boundary: 1.0e-02, FSI: 4.8e-03, Solid: 2.8e-02, Initial: 2.6e-04, LR: 6.14e-04
# INFO:src.utils.logger:Epoch 35000/60000, Total: 2.7e-02, Data(F): 8.3e-03, Data(S): 1.8e-02, Physics: 4.5e-03, Boundary: 8.7e-03, FSI: 5.2e-03, Solid: 2.3e-02, Initial: 3.6e-04, LR: 6.14e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.437e-03 |  Final right: 7.030e-04 |  Final bottom: 8.518e-05 |  Final up: 1.277e-02 |  Final solid: 3.222e-02 |  Final fluid_points: 5.945e-03 |  Final fluid: 3.975e-03 |  Final interface: 5.406e-03 |  Final initial: 2.586e-03 |  Final fluid_total: 3.491e-02 |  Final solid_total: 3.763e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 36000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 36000/60000, Total: 4.0e-02, Data(F): 1.1e-02, Data(S): 3.4e-02, Physics: 6.2e-03, Boundary: 1.5e-02, FSI: 4.9e-03, Solid: 3.9e-02, Initial: 2.4e-03, LR: 6.14e-04
# INFO:src.utils.logger:Epoch 37000/60000, Total: 3.3e-02, Data(F): 1.0e-02, Data(S): 1.6e-02, Physics: 7.3e-03, Boundary: 9.8e-03, FSI: 5.1e-03, Solid: 2.1e-02, Initial: 4.5e-04, LR: 6.14e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.428e-03 |  Final right: 2.079e-03 |  Final bottom: 2.143e-04 |  Final up: 1.158e-03 |  Final solid: 2.299e-02 |  Final fluid_points: 6.518e-03 |  Final fluid: 6.211e-03 |  Final interface: 5.834e-03 |  Final initial: 2.044e-04 |  Final fluid_total: 2.465e-02 |  Final solid_total: 2.882e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 38000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 38000/60000, Total: 2.6e-02, Data(F): 9.2e-03, Data(S): 1.8e-02, Physics: 4.6e-03, Boundary: 5.5e-03, FSI: 6.1e-03, Solid: 2.4e-02, Initial: 4.0e-04, LR: 6.14e-04
# INFO:src.utils.logger:Epoch 39000/60000, Total: 2.7e-02, Data(F): 9.6e-03, Data(S): 2.7e-02, Physics: 4.7e-03, Boundary: 6.5e-03, FSI: 5.4e-03, Solid: 3.2e-02, Initial: 3.8e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.017e-03 |  Final right: 1.239e-03 |  Final bottom: 1.412e-04 |  Final up: 4.097e-03 |  Final solid: 2.020e-02 |  Final fluid_points: 1.079e-02 |  Final fluid: 5.215e-03 |  Final interface: 6.346e-03 |  Final initial: 2.986e-04 |  Final fluid_total: 3.115e-02 |  Final solid_total: 2.654e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 40000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 40000/60000, Total: 2.2e-02, Data(F): 5.5e-03, Data(S): 2.1e-02, Physics: 6.6e-03, Boundary: 4.2e-03, FSI: 4.9e-03, Solid: 2.6e-02, Initial: 3.7e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 41000/60000, Total: 3.7e-02, Data(F): 9.0e-03, Data(S): 2.4e-02, Physics: 6.8e-03, Boundary: 1.5e-02, FSI: 5.8e-03, Solid: 2.9e-02, Initial: 4.6e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.656e-03 |  Final right: 1.367e-03 |  Final bottom: 1.146e-04 |  Final up: 3.110e-03 |  Final solid: 2.576e-02 |  Final fluid_points: 1.307e-02 |  Final fluid: 1.187e-02 |  Final interface: 4.585e-03 |  Final initial: 2.520e-04 |  Final fluid_total: 3.603e-02 |  Final solid_total: 3.035e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 42000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 42000/60000, Total: 2.6e-02, Data(F): 1.1e-02, Data(S): 2.0e-02, Physics: 4.7e-03, Boundary: 4.9e-03, FSI: 5.8e-03, Solid: 2.6e-02, Initial: 2.9e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 43000/60000, Total: 2.7e-02, Data(F): 1.1e-02, Data(S): 2.0e-02, Physics: 5.3e-03, Boundary: 5.4e-03, FSI: 5.3e-03, Solid: 2.5e-02, Initial: 5.0e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.369e-03 |  Final right: 1.539e-03 |  Final bottom: 2.244e-04 |  Final up: 2.602e-03 |  Final solid: 2.123e-02 |  Final fluid_points: 8.468e-03 |  Final fluid: 1.008e-02 |  Final interface: 6.167e-03 |  Final initial: 3.707e-04 |  Final fluid_total: 3.082e-02 |  Final solid_total: 2.740e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 44000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 44000/60000, Total: 3.3e-02, Data(F): 1.1e-02, Data(S): 2.8e-02, Physics: 7.7e-03, Boundary: 7.2e-03, FSI: 6.2e-03, Solid: 3.4e-02, Initial: 4.2e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 45000/60000, Total: 4.9e-02, Data(F): 7.7e-03, Data(S): 2.2e-02, Physics: 4.8e-03, Boundary: 2.9e-02, FSI: 6.2e-03, Solid: 2.8e-02, Initial: 7.5e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.567e-03 |  Final right: 1.881e-03 |  Final bottom: 2.198e-04 |  Final up: 1.741e-03 |  Final solid: 2.052e-02 |  Final fluid_points: 7.101e-03 |  Final fluid: 7.390e-03 |  Final interface: 5.436e-03 |  Final initial: 5.049e-04 |  Final fluid_total: 2.584e-02 |  Final solid_total: 2.595e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 46000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 46000/60000, Total: 3.4e-02, Data(F): 1.3e-02, Data(S): 2.0e-02, Physics: 5.3e-03, Boundary: 9.9e-03, FSI: 5.2e-03, Solid: 2.5e-02, Initial: 8.8e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 47000/60000, Total: 2.7e-02, Data(F): 5.6e-03, Data(S): 1.9e-02, Physics: 3.9e-03, Boundary: 1.2e-02, FSI: 5.3e-03, Solid: 2.5e-02, Initial: 3.6e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 9.213e-04 |  Final right: 8.594e-04 |  Final bottom: 1.163e-04 |  Final up: 4.155e-03 |  Final solid: 2.813e-02 |  Final fluid_points: 1.045e-02 |  Final fluid: 8.615e-03 |  Final interface: 6.099e-03 |  Final initial: 6.589e-04 |  Final fluid_total: 3.188e-02 |  Final solid_total: 3.423e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 48000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 48000/60000, Total: 3.4e-02, Data(F): 1.1e-02, Data(S): 3.8e-02, Physics: 6.4e-03, Boundary: 1.1e-02, FSI: 5.5e-03, Solid: 4.3e-02, Initial: 6.9e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 49000/60000, Total: 2.6e-02, Data(F): 5.1e-03, Data(S): 1.9e-02, Physics: 1.2e-02, Boundary: 3.9e-03, FSI: 5.2e-03, Solid: 2.4e-02, Initial: 3.7e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.457e-03 |  Final right: 2.016e-03 |  Final bottom: 4.719e-05 |  Final up: 5.530e-03 |  Final solid: 3.685e-02 |  Final fluid_points: 4.725e-03 |  Final fluid: 3.921e-03 |  Final interface: 5.825e-03 |  Final initial: 4.177e-04 |  Final fluid_total: 2.394e-02 |  Final solid_total: 4.267e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 50000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 50000/60000, Total: 2.5e-02, Data(F): 6.8e-03, Data(S): 3.0e-02, Physics: 4.9e-03, Boundary: 6.6e-03, FSI: 5.9e-03, Solid: 3.6e-02, Initial: 4.8e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 51000/60000, Total: 3.0e-02, Data(F): 1.4e-02, Data(S): 2.1e-02, Physics: 5.8e-03, Boundary: 5.7e-03, FSI: 5.1e-03, Solid: 2.6e-02, Initial: 2.9e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.631e-03 |  Final right: 5.288e-04 |  Final bottom: 5.550e-05 |  Final up: 1.795e-03 |  Final solid: 1.759e-02 |  Final fluid_points: 5.676e-03 |  Final fluid: 9.245e-03 |  Final interface: 6.600e-03 |  Final initial: 3.482e-04 |  Final fluid_total: 2.588e-02 |  Final solid_total: 2.419e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 52000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 52000/60000, Total: 2.6e-02, Data(F): 4.5e-03, Data(S): 1.8e-02, Physics: 7.2e-03, Boundary: 7.5e-03, FSI: 6.3e-03, Solid: 2.4e-02, Initial: 2.1e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 53000/60000, Total: 2.5e-02, Data(F): 8.2e-03, Data(S): 3.2e-02, Physics: 4.5e-03, Boundary: 5.9e-03, FSI: 5.8e-03, Solid: 3.8e-02, Initial: 4.8e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.757e-03 |  Final right: 3.664e-04 |  Final bottom: 7.025e-05 |  Final up: 1.695e-03 |  Final solid: 1.811e-02 |  Final fluid_points: 5.596e-03 |  Final fluid: 7.062e-03 |  Final interface: 4.911e-03 |  Final initial: 3.556e-04 |  Final fluid_total: 2.181e-02 |  Final solid_total: 2.302e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 54000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 54000/60000, Total: 3.4e-02, Data(F): 9.8e-03, Data(S): 2.5e-02, Physics: 4.0e-03, Boundary: 1.4e-02, FSI: 6.2e-03, Solid: 3.1e-02, Initial: 3.6e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 55000/60000, Total: 2.2e-02, Data(F): 4.8e-03, Data(S): 1.7e-02, Physics: 3.7e-03, Boundary: 7.3e-03, FSI: 5.7e-03, Solid: 2.3e-02, Initial: 4.3e-04, LR: 5.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.489e-03 |  Final right: 1.423e-03 |  Final bottom: 4.245e-05 |  Final up: 2.999e-03 |  Final solid: 2.645e-02 |  Final fluid_points: 5.005e-03 |  Final fluid: 1.072e-02 |  Final interface: 6.124e-03 |  Final initial: 3.987e-04 |  Final fluid_total: 2.820e-02 |  Final solid_total: 3.258e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 56000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 56000/60000, Total: 2.8e-02, Data(F): 4.9e-03, Data(S): 2.3e-02, Physics: 7.8e-03, Boundary: 9.6e-03, FSI: 4.8e-03, Solid: 2.8e-02, Initial: 6.8e-04, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 57000/60000, Total: 3.0e-02, Data(F): 7.7e-03, Data(S): 1.6e-02, Physics: 2.0e-03, Boundary: 1.4e-02, FSI: 5.8e-03, Solid: 2.2e-02, Initial: 5.7e-04, LR: 4.44e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.181e-03 |  Final right: 8.198e-04 |  Final bottom: 4.728e-05 |  Final up: 1.975e-03 |  Final solid: 1.641e-02 |  Final fluid_points: 1.139e-02 |  Final fluid: 6.669e-03 |  Final interface: 5.991e-03 |  Final initial: 2.037e-04 |  Final fluid_total: 2.827e-02 |  Final solid_total: 2.240e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 58000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Epoch 58000/60000, Total: 3.3e-02, Data(F): 1.1e-02, Data(S): 2.1e-02, Physics: 1.2e-02, Boundary: 4.0e-03, FSI: 5.7e-03, Solid: 2.7e-02, Initial: 1.9e-04, LR: 4.44e-04
# INFO:src.utils.logger:Epoch 59000/60000, Total: 1.8e-02, Data(F): 5.5e-03, Data(S): 2.3e-02, Physics: 4.0e-03, Boundary: 2.6e-03, FSI: 5.4e-03, Solid: 2.9e-02, Initial: 3.0e-04, LR: 4.44e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.107e-03 |  Final right: 1.409e-03 |  Final bottom: 8.290e-04 |  Final up: 6.493e-03 |  Final solid: 1.905e-02 |  Final fluid_points: 5.424e-03 |  Final fluid: 7.803e-03 |  Final interface: 5.273e-03 |  Final initial: 3.652e-04 |  Final fluid_total: 2.870e-02 |  Final solid_total: 2.432e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 60000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.107e-03 |  Final right: 1.409e-03 |  Final bottom: 8.290e-04 |  Final up: 6.493e-03 |  Final solid: 1.905e-02 |  Final fluid_points: 5.424e-03 |  Final fluid: 7.803e-03 |  Final interface: 5.273e-03 |  Final initial: 3.652e-04 |  Final fluid_total: 2.870e-02 |  Final solid_total: 2.432e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 60000 | Training checkpoint saved at ./checkpoints/2025-08-21_00-00-32-840132/model.pth
# INFO:src.utils.logger:Number of parameters: 323603
# final loss BC: 9.84e-03
# final loss Data: 1.90e-02
# final loss Fluid points: 5.42e-03
# final loss Physics: 7.80e-03
# final loss Initial: 3.65e-04
# /home/afrah/ubuntu/afrah/code/pinn_fsi_ibm/src/utils/plot_losses.py:139: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(bottom=y_min)
# Figure(1200x800)
# INFO:src.utils.logger:Relative L2 error for u: 1.53e+01 %
# INFO:src.utils.logger:Relative L2 error for v: 2.46e+01 %
# INFO:src.utils.logger:Relative L2 error for p: 4.43e+01 %
# INFO:src.utils.logger:On the interface
# INFO:src.utils.logger:Relative L2 error for u: 6.84e+00 %
# INFO:src.utils.logger:Relative L2 error for v: 8.54e+00 %
# INFO:src.utils.logger:Relative L2 error for p: 1.03e+02 %
# Figure(3000x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# INFO:src.utils.logger:On the Solid
# INFO:src.utils.logger:Relative L2 error for u: 7.57e+00 %
# INFO:src.utils.logger:Relative L2 error for v: 8.98e+00 %
# INFO:src.utils.logger:Relative L2 error for p: 1.17e+02 %

# %%
import torch
from src.utils.utils import lp_error
from src.utils.logger import Logging
from src.utils.colors import model_color

from src.nn.tanh import MLP
from src.nn.bspline import KAN
from src.utils.utils import clear_gpu_memory
from src.data.IBM_data_loader import prepare_training_data, visualize_tensor_datasets
from src.data.IBM_data_loader import load_fluid_testing_dataset
from src.models.m2_physics import PINNTrainer
from src.utils.plot_losses import plot_M1_loss_history
from src.utils.fsi_visualization import (
    create_frames,
    create_animations_from_existing_frames,
)
from src.data.IBM_data_loader import load_training_dataset

# %%
CHECKPOINT_PATH = "./checkpoints"
logger = Logging(CHECKPOINT_PATH)
model_dirname = logger.get_output_dir()

logger.print(model_dirname)
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-20_13-59-43-146571

# %%
clear_gpu_memory()
config = {
    "dataset_type": "old",
    "training_selection_method": "Sobol",
    "input_dim": 3,  # (x, y, z, t)
    "hidden_dim": 100,
    "hidden_layers_dim": 3,
    "fluid_density": 1.0,
    "fluid_viscosity": 0.01,
    "num_epochs": 60000,
    "batch_size": 128,
    "learning_rate": 1e-3,
    "data_weight": 2.0,
    "physics_weight": 0.01,
    "boundary_weight": 2.0,
    "fsi_weight": 0.5,
    "initial_weight": 4.0,
    "checkpoint_dir": "./checkpoints",
    "resume": None,
    "print_every": 10,
    "save_every": 20,
    "fluid_sampling_ratio": 0.01,
    "interface_sampling_ratio": 0.07,
    "solid_sampling_ratio": 0.07,
    "left_sampling_ratio": 0.1,
    "right_sampling_ratio": 0.15,
    "bottom_sampling_ratio": 0.1,
    "top_sampling_ratio": 0.1,
    "initial_sampling_ratio": 0.1,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    "solver": "kan",
    "model": "m2",
}
# Out:
# GPU memory cleared!

# %%
training_data["interface"][: , 0:1].min()
# Out:
# tensor(0., device='cuda:0')

# %%
logger.print("Config:")
for key, value in config.items():
    logger.print(f"{key}: {value}")

training_data_path = "./data/training_dataset/old"

training_data = None #load_training_dataset(training_data_path, device=config["device"])

if training_data is None:
    training_data = prepare_training_data(
        config["dataset_type"],
        fluid_sampling_ratio=config["fluid_sampling_ratio"],
        interface_sampling_ratio=config["interface_sampling_ratio"],
        solid_sampling_ratio=config["solid_sampling_ratio"],
        left_sampling_ratio=config["left_sampling_ratio"],
        right_sampling_ratio=config["right_sampling_ratio"],
        bottom_sampling_ratio=config["bottom_sampling_ratio"],
        top_sampling_ratio=config["top_sampling_ratio"],
        initial_sampling_ratio=config["initial_sampling_ratio"],
        training_selection_method=config["training_selection_method"],
        device=config["device"],
        save_dir=training_data_path,
    )
# Out:
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 100
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 128
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.01
# INFO:src.utils.logger:boundary_weight: 2.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 4.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 10
# INFO:src.utils.logger:save_every: 20
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.07
# INFO:src.utils.logger:solid_sampling_ratio: 0.07
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.15
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.1
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cuda
# INFO:src.utils.logger:solver: kan
# INFO:src.utils.logger:model: m2
# Saved fluid tensor with shape torch.Size([10508, 8]) to ./data/training_dataset/old/fluid_tensor.pt
# Saved fluid_points tensor with shape torch.Size([3986, 8]) to ./data/training_dataset/old/fluid_points_tensor.pt
# Saved interface tensor with shape torch.Size([10166, 11]) to ./data/training_dataset/old/interface_tensor.pt
# Saved solid tensor with shape torch.Size([10166, 8]) to ./data/training_dataset/old/solid_tensor.pt
# Saved left tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/left_tensor.pt
# Saved right tensor with shape torch.Size([1545, 8]) to ./data/training_dataset/old/right_tensor.pt
# Saved bottom tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/bottom_tensor.pt
# Saved up tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/up_tensor.pt
# Saved initial tensor with shape torch.Size([1330, 8]) to ./data/training_dataset/old/initial_tensor.pt

# %%
visualize_tensor_datasets(training_data, save_dir=training_data_path)

fluid_network = (
    [config["input_dim"]] + [config["hidden_dim"]] * config["hidden_layers_dim"] + [3]
)
if config["solver"] == "mlp":
    fluid_model = MLP(network=fluid_network)
    solid_model = MLP(network=fluid_network)
else:
    fluid_model = KAN(fluid_network)
    solid_model = KAN(fluid_network)

logger.print("Fluid model architecture:")
logger.print(fluid_model)
logger.print(solid_model)
logger.print(
    f"Number of parameters: {sum(p.numel() for p in fluid_model.parameters())}"
)
# Out:
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:KAN(
#   (layers): ModuleList(
#     (0-3): 4 x KANLinear(
#       (base_activation): SiLU()
#     )
#   )
# )
# INFO:src.utils.logger:KAN(
#   (layers): ModuleList(
#     (0-3): 4 x KANLinear(
#       (base_activation): SiLU()
#     )
#   )
# )
# INFO:src.utils.logger:Number of parameters: 206000

# %%
trainer = PINNTrainer(
    fluid_model=fluid_model,
    solid_model=solid_model,
    training_data=training_data,
    learning_rate=config["learning_rate"],
    logger=logger,
    device=config["device"],
    fluid_density=config["fluid_density"],
    fluid_viscosity=config["fluid_viscosity"],
    print_every=config["print_every"],
    save_every=config["save_every"],
    solver=config["solver"],
    model=config["model"],
)


loss_history = trainer.train(
    num_epochs=config["num_epochs"],
    batch_size=config["batch_size"],
    data_weight=config["data_weight"],
    physics_weight=config["physics_weight"],
    boundary_weight=config["boundary_weight"],
    fsi_weight=config["fsi_weight"],
    initial_weight=config["initial_weight"],
)
