# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python -m src.trainer.m1_mlp_trainer
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-20_23-47-50-130273
# GPU memory cleared!
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 400
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 256
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.005
# INFO:src.utils.logger:boundary_weight: 4.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 0.5
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 1000
# INFO:src.utils.logger:save_every: 2000
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.05
# INFO:src.utils.logger:solid_sampling_ratio: 0.01
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.1
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.15
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cuda
# INFO:src.utils.logger:solver: mlp
# INFO:src.utils.logger:model: m1
# Saved fluid tensor with shape torch.Size([10508, 8]) to ./data/training_dataset/old/fluid_tensor.pt
# Saved fluid_points tensor with shape torch.Size([3986, 8]) to ./data/training_dataset/old/fluid_points_tensor.pt
# Saved interface tensor with shape torch.Size([7262, 11]) to ./data/training_dataset/old/interface_tensor.pt
# Saved solid tensor with shape torch.Size([1452, 8]) to ./data/training_dataset/old/solid_tensor.pt
# Saved left tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/left_tensor.pt
# Saved right tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/right_tensor.pt
# Saved bottom tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/bottom_tensor.pt
# Saved up tensor with shape torch.Size([1545, 8]) to ./data/training_dataset/old/up_tensor.pt
# Saved initial tensor with shape torch.Size([1330, 8]) to ./data/training_dataset/old/initial_tensor.pt
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=400, bias=True)
#     (1-2): 2 x Linear(in_features=400, out_features=400, bias=True)
#     (3): Linear(in_features=400, out_features=3, bias=True)
#   )
# )
# INFO:src.utils.logger:Number of parameters: 323603
# INFO:src.utils.logger:Epoch 0/60000, Total: 4.6e+00, Data(F): 1.4e-01, Data(S): 9.6e-02, Physics: 3.6e-04, Boundary: 4.4e+00, FSI: 2.7e-02, Initial: 1.3e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1000/60000, Total: 4.5e-01, Data(F): 8.2e-02, Data(S): 5.1e-02, Physics: 1.2e-03, Boundary: 2.9e-01, FSI: 5.8e-03, Initial: 1.8e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.618e-02 |  Final right: 4.821e-02 |  Final bottom: 1.592e-03 |  Final up: 7.645e-02 |  Final solid: 2.929e-02 |  Final fluid_points: 3.196e-02 |  Final fluid: 1.622e-03 |  Final interface: 7.885e-03 |  Final initial: 8.784e-03 |  Final total: 2.220e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 2000/60000, Total: 1.9e-01, Data(F): 3.2e-02, Data(S): 2.1e-02, Physics: 2.0e-03, Boundary: 1.1e-01, FSI: 1.9e-02, Initial: 1.1e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 3000/60000, Total: 1.8e-01, Data(F): 3.7e-02, Data(S): 1.8e-02, Physics: 4.7e-03, Boundary: 1.0e-01, FSI: 9.5e-03, Initial: 5.8e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.052e-02 |  Final right: 2.086e-02 |  Final bottom: 3.857e-04 |  Final up: 2.757e-02 |  Final solid: 2.431e-02 |  Final fluid_points: 2.814e-02 |  Final fluid: 7.512e-03 |  Final interface: 1.125e-02 |  Final initial: 4.575e-03 |  Final total: 1.351e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 4000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 4000/60000, Total: 1.2e-01, Data(F): 1.9e-02, Data(S): 1.6e-02, Physics: 7.3e-03, Boundary: 6.5e-02, FSI: 7.4e-03, Initial: 5.8e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 5000/60000, Total: 1.3e-01, Data(F): 2.5e-02, Data(S): 1.4e-02, Physics: 7.9e-03, Boundary: 6.8e-02, FSI: 7.7e-03, Initial: 4.5e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 6.048e-03 |  Final right: 2.546e-02 |  Final bottom: 1.548e-03 |  Final up: 2.451e-02 |  Final solid: 1.616e-02 |  Final fluid_points: 3.176e-02 |  Final fluid: 9.583e-03 |  Final interface: 4.146e-03 |  Final initial: 2.908e-03 |  Final total: 1.221e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 6000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 6000/60000, Total: 1.6e-01, Data(F): 2.1e-02, Data(S): 2.4e-02, Physics: 9.6e-03, Boundary: 8.7e-02, FSI: 1.2e-02, Initial: 3.4e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 7000/60000, Total: 1.0e-01, Data(F): 1.8e-02, Data(S): 1.0e-02, Physics: 8.9e-03, Boundary: 5.7e-02, FSI: 7.0e-03, Initial: 2.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.650e-03 |  Final right: 4.199e-03 |  Final bottom: 1.496e-03 |  Final up: 3.472e-02 |  Final solid: 1.428e-02 |  Final fluid_points: 1.347e-02 |  Final fluid: 4.977e-03 |  Final interface: 6.852e-03 |  Final initial: 3.881e-03 |  Final total: 8.753e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 8000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 8000/60000, Total: 1.3e-01, Data(F): 3.5e-02, Data(S): 1.8e-02, Physics: 9.3e-03, Boundary: 5.6e-02, FSI: 4.6e-03, Initial: 3.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 9000/60000, Total: 9.8e-02, Data(F): 2.0e-02, Data(S): 1.2e-02, Physics: 1.0e-02, Boundary: 4.7e-02, FSI: 6.1e-03, Initial: 2.5e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 4.968e-03 |  Final right: 8.875e-03 |  Final bottom: 9.385e-04 |  Final up: 3.151e-02 |  Final solid: 6.074e-03 |  Final fluid_points: 9.542e-03 |  Final fluid: 1.355e-02 |  Final interface: 4.452e-03 |  Final initial: 3.498e-03 |  Final total: 8.340e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 10000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 10000/60000, Total: 9.5e-02, Data(F): 1.8e-02, Data(S): 1.3e-02, Physics: 9.5e-03, Boundary: 4.5e-02, FSI: 6.6e-03, Initial: 2.9e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 11000/60000, Total: 9.0e-02, Data(F): 2.3e-02, Data(S): 7.7e-03, Physics: 1.1e-02, Boundary: 3.8e-02, FSI: 5.5e-03, Initial: 4.3e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 8.338e-03 |  Final right: 3.780e-03 |  Final bottom: 3.903e-04 |  Final up: 1.193e-02 |  Final solid: 7.530e-03 |  Final fluid_points: 1.783e-02 |  Final fluid: 6.486e-03 |  Final interface: 5.223e-03 |  Final initial: 1.543e-03 |  Final total: 6.305e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 12000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 12000/60000, Total: 7.1e-02, Data(F): 1.3e-02, Data(S): 5.7e-03, Physics: 1.4e-02, Boundary: 2.9e-02, FSI: 7.7e-03, Initial: 1.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 13000/60000, Total: 6.8e-02, Data(F): 1.1e-02, Data(S): 5.9e-03, Physics: 8.7e-03, Boundary: 3.4e-02, FSI: 6.7e-03, Initial: 1.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 7.562e-03 |  Final right: 7.008e-03 |  Final bottom: 4.345e-04 |  Final up: 1.686e-02 |  Final solid: 7.004e-03 |  Final fluid_points: 1.077e-02 |  Final fluid: 7.301e-03 |  Final interface: 7.218e-03 |  Final initial: 1.265e-03 |  Final total: 6.543e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 14000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 14000/60000, Total: 6.8e-02, Data(F): 9.4e-03, Data(S): 8.2e-03, Physics: 1.4e-02, Boundary: 3.1e-02, FSI: 4.7e-03, Initial: 1.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 15000/60000, Total: 5.2e-02, Data(F): 1.6e-02, Data(S): 6.8e-03, Physics: 5.7e-03, Boundary: 1.6e-02, FSI: 5.5e-03, Initial: 2.0e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.618e-03 |  Final right: 1.678e-03 |  Final bottom: 2.596e-04 |  Final up: 2.153e-02 |  Final solid: 7.233e-03 |  Final fluid_points: 1.013e-02 |  Final fluid: 7.169e-03 |  Final interface: 7.692e-03 |  Final initial: 5.773e-04 |  Final total: 5.889e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 16000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 16000/60000, Total: 5.0e-02, Data(F): 7.8e-03, Data(S): 9.6e-03, Physics: 6.3e-03, Boundary: 1.8e-02, FSI: 6.7e-03, Initial: 1.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 17000/60000, Total: 7.2e-02, Data(F): 1.2e-02, Data(S): 1.5e-02, Physics: 1.2e-02, Boundary: 3.0e-02, FSI: 3.6e-03, Initial: 9.2e-04, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.175e-02 |  Final right: 7.280e-03 |  Final bottom: 2.236e-03 |  Final up: 1.861e-02 |  Final solid: 6.251e-03 |  Final fluid_points: 1.464e-02 |  Final fluid: 4.457e-03 |  Final interface: 6.749e-03 |  Final initial: 1.314e-03 |  Final total: 7.330e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 18000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 18000/60000, Total: 7.8e-02, Data(F): 1.1e-02, Data(S): 1.2e-02, Physics: 9.6e-03, Boundary: 3.5e-02, FSI: 8.7e-03, Initial: 1.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 19000/60000, Total: 4.3e-02, Data(F): 7.9e-03, Data(S): 8.5e-03, Physics: 7.2e-03, Boundary: 1.3e-02, FSI: 4.8e-03, Initial: 1.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.051e-03 |  Final right: 2.079e-03 |  Final bottom: 2.001e-04 |  Final up: 7.590e-03 |  Final solid: 5.844e-03 |  Final fluid_points: 9.271e-03 |  Final fluid: 1.023e-02 |  Final interface: 7.131e-03 |  Final initial: 1.440e-03 |  Final total: 4.684e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 20000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 20000/60000, Total: 5.6e-02, Data(F): 1.0e-02, Data(S): 1.3e-02, Physics: 1.2e-02, Boundary: 1.1e-02, FSI: 8.4e-03, Initial: 1.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 21000/60000, Total: 4.1e-02, Data(F): 4.6e-03, Data(S): 4.9e-03, Physics: 5.1e-03, Boundary: 1.7e-02, FSI: 8.8e-03, Initial: 1.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.783e-03 |  Final right: 2.879e-03 |  Final bottom: 8.014e-04 |  Final up: 7.121e-03 |  Final solid: 6.524e-03 |  Final fluid_points: 8.135e-03 |  Final fluid: 1.834e-02 |  Final interface: 6.854e-03 |  Final initial: 7.982e-04 |  Final total: 5.424e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 22000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 22000/60000, Total: 5.0e-02, Data(F): 9.3e-03, Data(S): 4.7e-03, Physics: 6.0e-03, Boundary: 2.1e-02, FSI: 7.7e-03, Initial: 8.5e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 23000/60000, Total: 4.9e-02, Data(F): 9.7e-03, Data(S): 6.3e-03, Physics: 1.1e-02, Boundary: 1.7e-02, FSI: 4.0e-03, Initial: 7.2e-04, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 5.350e-03 |  Final right: 4.698e-03 |  Final bottom: 1.032e-03 |  Final up: 8.709e-03 |  Final solid: 5.671e-03 |  Final fluid_points: 9.886e-03 |  Final fluid: 9.212e-03 |  Final interface: 6.526e-03 |  Final initial: 6.095e-04 |  Final total: 5.169e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 24000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 24000/60000, Total: 4.3e-02, Data(F): 7.6e-03, Data(S): 7.5e-03, Physics: 6.3e-03, Boundary: 1.2e-02, FSI: 8.9e-03, Initial: 7.5e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 25000/60000, Total: 5.3e-02, Data(F): 8.0e-03, Data(S): 9.8e-03, Physics: 9.6e-03, Boundary: 1.5e-02, FSI: 7.9e-03, Initial: 1.8e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.869e-03 |  Final right: 3.432e-03 |  Final bottom: 1.858e-04 |  Final up: 5.408e-03 |  Final solid: 7.907e-03 |  Final fluid_points: 6.801e-03 |  Final fluid: 6.223e-03 |  Final interface: 7.414e-03 |  Final initial: 9.966e-04 |  Final total: 4.124e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 26000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 26000/60000, Total: 4.2e-02, Data(F): 5.7e-03, Data(S): 7.2e-03, Physics: 4.9e-03, Boundary: 1.5e-02, FSI: 8.7e-03, Initial: 6.6e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 27000/60000, Total: 4.1e-02, Data(F): 6.0e-03, Data(S): 5.2e-03, Physics: 1.1e-02, Boundary: 1.1e-02, FSI: 7.7e-03, Initial: 1.0e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.709e-03 |  Final right: 8.160e-04 |  Final bottom: 9.623e-05 |  Final up: 1.674e-02 |  Final solid: 9.859e-03 |  Final fluid_points: 7.274e-03 |  Final fluid: 7.680e-03 |  Final interface: 6.842e-03 |  Final initial: 4.914e-04 |  Final total: 5.251e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 28000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 28000/60000, Total: 4.2e-02, Data(F): 4.8e-03, Data(S): 6.1e-03, Physics: 5.0e-03, Boundary: 1.8e-02, FSI: 7.0e-03, Initial: 8.2e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 29000/60000, Total: 4.3e-02, Data(F): 5.5e-03, Data(S): 6.2e-03, Physics: 9.2e-03, Boundary: 1.3e-02, FSI: 7.9e-03, Initial: 7.6e-04, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 7.182e-03 |  Final right: 2.651e-03 |  Final bottom: 3.671e-04 |  Final up: 9.167e-03 |  Final solid: 5.998e-03 |  Final fluid_points: 9.418e-03 |  Final fluid: 6.227e-03 |  Final interface: 9.784e-03 |  Final initial: 9.258e-04 |  Final total: 5.172e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 30000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 30000/60000, Total: 5.8e-02, Data(F): 1.6e-02, Data(S): 4.4e-03, Physics: 7.3e-03, Boundary: 2.4e-02, FSI: 5.5e-03, Initial: 1.0e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 31000/60000, Total: 3.8e-02, Data(F): 6.8e-03, Data(S): 6.1e-03, Physics: 3.9e-03, Boundary: 1.4e-02, FSI: 6.2e-03, Initial: 1.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.282e-03 |  Final right: 1.837e-03 |  Final bottom: 9.831e-05 |  Final up: 1.151e-02 |  Final solid: 5.568e-03 |  Final fluid_points: 6.590e-03 |  Final fluid: 1.228e-02 |  Final interface: 7.763e-03 |  Final initial: 1.143e-03 |  Final total: 4.907e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 32000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 32000/60000, Total: 4.4e-02, Data(F): 6.1e-03, Data(S): 9.7e-03, Physics: 6.2e-03, Boundary: 1.7e-02, FSI: 3.2e-03, Initial: 1.6e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 33000/60000, Total: 3.1e-02, Data(F): 4.4e-03, Data(S): 5.0e-03, Physics: 6.6e-03, Boundary: 1.0e-02, FSI: 4.6e-03, Initial: 3.6e-04, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.403e-03 |  Final right: 2.116e-03 |  Final bottom: 5.647e-04 |  Final up: 5.041e-03 |  Final solid: 4.495e-03 |  Final fluid_points: 5.411e-03 |  Final fluid: 1.758e-02 |  Final interface: 8.679e-03 |  Final initial: 6.757e-04 |  Final total: 4.596e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 34000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 34000/60000, Total: 6.2e-02, Data(F): 5.8e-03, Data(S): 9.8e-03, Physics: 2.3e-02, Boundary: 1.6e-02, FSI: 7.2e-03, Initial: 5.1e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 35000/60000, Total: 4.6e-02, Data(F): 5.4e-03, Data(S): 5.5e-03, Physics: 9.7e-03, Boundary: 1.7e-02, FSI: 6.8e-03, Initial: 7.8e-04, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.005e-03 |  Final right: 2.531e-03 |  Final bottom: 1.734e-04 |  Final up: 5.517e-03 |  Final solid: 7.290e-03 |  Final fluid_points: 4.982e-03 |  Final fluid: 1.065e-02 |  Final interface: 5.161e-03 |  Final initial: 3.996e-04 |  Final total: 3.871e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 36000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 36000/60000, Total: 3.2e-02, Data(F): 6.8e-03, Data(S): 4.0e-03, Physics: 5.1e-03, Boundary: 8.4e-03, FSI: 6.8e-03, Initial: 5.8e-04, LR: 9.50e-04
# INFO:src.utils.logger:Epoch 37000/60000, Total: 4.7e-02, Data(F): 1.0e-02, Data(S): 4.8e-03, Physics: 7.1e-03, Boundary: 1.7e-02, FSI: 6.8e-03, Initial: 4.7e-04, LR: 9.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.490e-03 |  Final right: 8.725e-04 |  Final bottom: 1.507e-04 |  Final up: 7.283e-03 |  Final solid: 4.798e-03 |  Final fluid_points: 5.760e-03 |  Final fluid: 1.147e-02 |  Final interface: 9.052e-03 |  Final initial: 5.004e-04 |  Final total: 4.337e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 38000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 38000/60000, Total: 3.5e-02, Data(F): 6.0e-03, Data(S): 4.7e-03, Physics: 8.9e-03, Boundary: 9.2e-03, FSI: 6.2e-03, Initial: 4.6e-04, LR: 9.50e-04
# INFO:src.utils.logger:Epoch 39000/60000, Total: 3.2e-02, Data(F): 4.6e-03, Data(S): 5.4e-03, Physics: 6.6e-03, Boundary: 9.1e-03, FSI: 5.0e-03, Initial: 1.1e-03, LR: 9.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.962e-03 |  Final right: 1.931e-03 |  Final bottom: 2.466e-04 |  Final up: 5.574e-03 |  Final solid: 6.020e-03 |  Final fluid_points: 5.424e-03 |  Final fluid: 2.009e-02 |  Final interface: 3.737e-03 |  Final initial: 4.582e-04 |  Final total: 4.644e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 40000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 40000/60000, Total: 4.3e-02, Data(F): 6.5e-03, Data(S): 5.5e-03, Physics: 6.5e-03, Boundary: 1.4e-02, FSI: 9.7e-03, Initial: 7.4e-04, LR: 9.50e-04
# INFO:src.utils.logger:Epoch 41000/60000, Total: 3.9e-02, Data(F): 7.1e-03, Data(S): 5.5e-03, Physics: 8.8e-03, Boundary: 1.2e-02, FSI: 4.7e-03, Initial: 5.6e-04, LR: 9.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.282e-03 |  Final right: 3.381e-03 |  Final bottom: 2.793e-04 |  Final up: 5.149e-03 |  Final solid: 7.867e-03 |  Final fluid_points: 7.103e-03 |  Final fluid: 1.295e-02 |  Final interface: 7.662e-03 |  Final initial: 4.578e-04 |  Final total: 4.713e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 42000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 42000/60000, Total: 5.6e-02, Data(F): 6.0e-03, Data(S): 5.6e-03, Physics: 8.2e-03, Boundary: 2.8e-02, FSI: 7.5e-03, Initial: 5.9e-04, LR: 9.50e-04
# INFO:src.utils.logger:Epoch 43000/60000, Total: 3.0e-02, Data(F): 4.4e-03, Data(S): 4.6e-03, Physics: 5.8e-03, Boundary: 1.0e-02, FSI: 4.9e-03, Initial: 5.6e-04, LR: 9.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.979e-03 |  Final right: 9.121e-04 |  Final bottom: 1.918e-04 |  Final up: 5.240e-03 |  Final solid: 8.783e-03 |  Final fluid_points: 6.244e-03 |  Final fluid: 9.055e-03 |  Final interface: 5.242e-03 |  Final initial: 4.546e-04 |  Final total: 3.810e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 44000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 44000/60000, Total: 4.9e-02, Data(F): 5.2e-03, Data(S): 8.3e-03, Physics: 1.1e-02, Boundary: 1.5e-02, FSI: 9.2e-03, Initial: 4.4e-04, LR: 9.02e-04
# INFO:src.utils.logger:Epoch 45000/60000, Total: 3.9e-02, Data(F): 9.5e-03, Data(S): 4.1e-03, Physics: 5.2e-03, Boundary: 1.1e-02, FSI: 9.1e-03, Initial: 4.9e-04, LR: 9.02e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.219e-03 |  Final right: 1.840e-03 |  Final bottom: 3.812e-04 |  Final up: 1.633e-02 |  Final solid: 4.041e-03 |  Final fluid_points: 1.125e-02 |  Final fluid: 9.066e-03 |  Final interface: 7.036e-03 |  Final initial: 6.262e-04 |  Final total: 5.279e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 46000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 46000/60000, Total: 2.8e-02, Data(F): 4.9e-03, Data(S): 6.6e-03, Physics: 5.1e-03, Boundary: 3.7e-03, FSI: 5.6e-03, Initial: 2.2e-03, LR: 9.02e-04
# INFO:src.utils.logger:Epoch 47000/60000, Total: 6.1e-02, Data(F): 5.9e-03, Data(S): 6.2e-03, Physics: 7.4e-03, Boundary: 3.0e-02, FSI: 6.2e-03, Initial: 5.2e-03, LR: 9.02e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.795e-03 |  Final right: 1.318e-03 |  Final bottom: 1.482e-04 |  Final up: 5.241e-03 |  Final solid: 7.760e-03 |  Final fluid_points: 5.008e-03 |  Final fluid: 1.141e-02 |  Final interface: 6.735e-03 |  Final initial: 1.071e-03 |  Final total: 4.049e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 48000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 48000/60000, Total: 4.0e-02, Data(F): 4.3e-03, Data(S): 4.3e-03, Physics: 9.5e-03, Boundary: 1.1e-02, FSI: 9.8e-03, Initial: 6.5e-04, LR: 9.02e-04
# INFO:src.utils.logger:Epoch 49000/60000, Total: 4.3e-02, Data(F): 1.4e-02, Data(S): 5.0e-03, Physics: 5.6e-03, Boundary: 1.2e-02, FSI: 6.4e-03, Initial: 6.5e-04, LR: 9.02e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.369e-03 |  Final right: 9.998e-04 |  Final bottom: 1.852e-04 |  Final up: 4.701e-03 |  Final solid: 4.269e-03 |  Final fluid_points: 1.071e-02 |  Final fluid: 6.513e-03 |  Final interface: 5.686e-03 |  Final initial: 4.365e-04 |  Final total: 3.487e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 50000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 50000/60000, Total: 5.7e-02, Data(F): 6.3e-03, Data(S): 7.9e-03, Physics: 1.7e-02, Boundary: 1.8e-02, FSI: 7.7e-03, Initial: 4.2e-04, LR: 9.02e-04
# INFO:src.utils.logger:Epoch 51000/60000, Total: 5.1e-02, Data(F): 7.3e-03, Data(S): 5.2e-03, Physics: 1.3e-02, Boundary: 1.9e-02, FSI: 6.6e-03, Initial: 6.7e-04, LR: 9.02e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.224e-03 |  Final right: 3.146e-03 |  Final bottom: 6.673e-05 |  Final up: 6.366e-03 |  Final solid: 6.242e-03 |  Final fluid_points: 4.746e-03 |  Final fluid: 8.425e-03 |  Final interface: 4.847e-03 |  Final initial: 3.208e-04 |  Final total: 3.738e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 52000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 52000/60000, Total: 2.8e-02, Data(F): 6.5e-03, Data(S): 3.9e-03, Physics: 4.6e-03, Boundary: 7.5e-03, FSI: 5.6e-03, Initial: 2.1e-04, LR: 9.02e-04
# INFO:src.utils.logger:Epoch 53000/60000, Total: 4.8e-02, Data(F): 9.8e-03, Data(S): 4.6e-03, Physics: 1.2e-02, Boundary: 1.7e-02, FSI: 4.2e-03, Initial: 9.4e-04, LR: 9.02e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.006e-03 |  Final right: 3.593e-03 |  Final bottom: 7.711e-04 |  Final up: 1.017e-02 |  Final solid: 5.044e-03 |  Final fluid_points: 8.807e-03 |  Final fluid: 9.262e-03 |  Final interface: 7.091e-03 |  Final initial: 9.336e-04 |  Final total: 4.768e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 54000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 54000/60000, Total: 4.3e-02, Data(F): 7.6e-03, Data(S): 9.0e-03, Physics: 5.2e-03, Boundary: 1.5e-02, FSI: 5.6e-03, Initial: 5.3e-04, LR: 9.02e-04
# INFO:src.utils.logger:Epoch 55000/60000, Total: 3.8e-02, Data(F): 7.4e-03, Data(S): 6.0e-03, Physics: 4.0e-03, Boundary: 1.3e-02, FSI: 6.3e-03, Initial: 7.1e-04, LR: 9.02e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.682e-03 |  Final right: 1.715e-03 |  Final bottom: 1.715e-04 |  Final up: 2.518e-03 |  Final solid: 6.072e-03 |  Final fluid_points: 4.911e-03 |  Final fluid: 5.472e-03 |  Final interface: 4.960e-03 |  Final initial: 4.291e-04 |  Final total: 2.893e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 56000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 56000/60000, Total: 4.0e-02, Data(F): 8.2e-03, Data(S): 1.0e-02, Physics: 8.3e-03, Boundary: 8.8e-03, FSI: 3.9e-03, Initial: 5.5e-04, LR: 9.02e-04
# INFO:src.utils.logger:Epoch 57000/60000, Total: 8.3e-02, Data(F): 1.3e-02, Data(S): 1.1e-02, Physics: 1.2e-02, Boundary: 3.8e-02, FSI: 7.8e-03, Initial: 1.0e-03, LR: 9.02e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.307e-03 |  Final right: 1.311e-03 |  Final bottom: 2.197e-04 |  Final up: 5.701e-03 |  Final solid: 4.334e-03 |  Final fluid_points: 6.445e-03 |  Final fluid: 7.087e-03 |  Final interface: 3.924e-03 |  Final initial: 5.067e-04 |  Final total: 3.184e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 58000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Epoch 58000/60000, Total: 3.7e-02, Data(F): 4.2e-03, Data(S): 1.0e-02, Physics: 5.9e-03, Boundary: 6.8e-03, FSI: 9.5e-03, Initial: 4.5e-04, LR: 9.02e-04
# INFO:src.utils.logger:Epoch 59000/60000, Total: 4.3e-02, Data(F): 6.4e-03, Data(S): 5.0e-03, Physics: 1.5e-02, Boundary: 9.2e-03, FSI: 7.2e-03, Initial: 6.4e-04, LR: 9.02e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.563e-03 |  Final right: 1.411e-03 |  Final bottom: 7.454e-05 |  Final up: 3.784e-03 |  Final solid: 8.072e-03 |  Final fluid_points: 4.247e-03 |  Final fluid: 6.250e-03 |  Final interface: 4.135e-03 |  Final initial: 3.350e-04 |  Final total: 2.987e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 60000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.563e-03 |  Final right: 1.411e-03 |  Final bottom: 7.454e-05 |  Final up: 3.784e-03 |  Final solid: 8.072e-03 |  Final fluid_points: 4.247e-03 |  Final fluid: 6.250e-03 |  Final interface: 4.135e-03 |  Final initial: 3.350e-04 |  Final total: 2.987e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 60000 | Training checkpoint saved at ./checkpoints/2025-08-20_23-47-50-130273/model.pth
# INFO:src.utils.logger:Number of parameters: 323603
# final loss BC: 6.83e-03
# final loss Data: 8.07e-03
# final loss Fluid points: 4.25e-03
# final loss Physics: 6.25e-03
# final loss Initial: 3.35e-04
# /home/afrah/ubuntu/afrah/code/pinn_fsi_ibm/src/utils/plot_losses.py:139: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(bottom=y_min)
# Figure(1200x800)
# INFO:src.utils.logger:Relative L2 error for u: 1.43e+01 %
# INFO:src.utils.logger:Relative L2 error for v: 2.42e+01 %
# INFO:src.utils.logger:Relative L2 error for p: 4.52e+01 %
# INFO:src.utils.logger:On the interface
# INFO:src.utils.logger:Relative L2 error for u: 1.89e+01 %
# INFO:src.utils.logger:Relative L2 error for v: 2.20e+01 %
# INFO:src.utils.logger:Relative L2 error for p: 6.75e+01 %
# Figure(3000x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# Figure(900x600)
# INFO:src.utils.logger:On the Solid
# INFO:src.utils.logger:Relative L2 error for u: 1.23e+01 %
# INFO:src.utils.logger:Relative L2 error for v: 1.61e+01 %
# INFO:src.utils.logger:Relative L2 error for p: 5.49e+01 %

# %%
import torch
from src.utils.utils import lp_error
from src.utils.logger import Logging
from src.utils.colors import model_color

from src.nn.tanh import MLP
from src.nn.bspline import KAN
from src.utils.utils import clear_gpu_memory
from src.data.IBM_data_loader import prepare_training_data, visualize_tensor_datasets
from src.data.IBM_data_loader import load_fluid_testing_dataset
from src.models.m1_physics import PINNTrainer
from src.utils.plot_losses import plot_M1_loss_history
from src.utils.fsi_visualization import (
    create_frames,
    create_animations_from_existing_frames,
)
from src.data.IBM_data_loader import load_training_dataset

# %%
CHECKPOINT_PATH = "./checkpoints"
logger = Logging(CHECKPOINT_PATH)
model_dirname = logger.get_output_dir()

logger.print(model_dirname)
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-18_13-51-53-682395

# %%
clear_gpu_memory()
config = {
    "dataset_type": "old",
    "training_selection_method": "Sobol",
    "input_dim": 3,  # (x, y, z, t)
    "hidden_dim": 100,
    "hidden_layers_dim": 3,
    "fluid_density": 1.0,
    "fluid_viscosity": 0.01,
    "num_epochs": 60000,
    "batch_size": 128,
    "learning_rate": 1e-3,
    "data_weight": 2.0,
    "physics_weight": 0.01,
    "boundary_weight": 2.0,
    "fsi_weight": 0.5,
    "initial_weight": 4.0,
    "checkpoint_dir": "./checkpoints",
    "resume": None,
    "print_every": 100,
    "save_every": 200,
    "fluid_sampling_ratio": 0.01,
    "interface_sampling_ratio": 0.07,
    "solid_sampling_ratio": 0.0,
    "left_sampling_ratio": 0.1,
    "right_sampling_ratio": 0.15,
    "bottom_sampling_ratio": 0.1,
    "top_sampling_ratio": 0.1,
    "initial_sampling_ratio": 0.1,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    "solver": "kan",
    "model": "m1",
}
# Out:
# GPU memory cleared!

# %%
logger.print("Config:")
for key, value in config.items():
    logger.print(f"{key}: {value}")

training_data_path = "./data/training_dataset/old"

training_data = load_training_dataset(training_data_path, device=config["device"])

if training_data is None:
    training_data = prepare_training_data(
        config["dataset_type"],
        fluid_sampling_ratio=config["fluid_sampling_ratio"],
        interface_sampling_ratio=config["interface_sampling_ratio"],
        solid_sampling_ratio=config["solid_sampling_ratio"],
        left_sampling_ratio=config["left_sampling_ratio"],
        right_sampling_ratio=config["right_sampling_ratio"],
        bottom_sampling_ratio=config["bottom_sampling_ratio"],
        top_sampling_ratio=config["top_sampling_ratio"],
        initial_sampling_ratio=config["initial_sampling_ratio"],
        training_selection_method=config["training_selection_method"],
        device=config["device"],
        save_dir=training_data_path,
    )
# Out:
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 100
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 128
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.01
# INFO:src.utils.logger:boundary_weight: 2.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 4.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 100
# INFO:src.utils.logger:save_every: 200
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.07
# INFO:src.utils.logger:solid_sampling_ratio: 0.0
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.15
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.1
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cpu
# INFO:src.utils.logger:solver: kan
# INFO:src.utils.logger:model: m1
# Loaded interface tensor from ./data/training_dataset/old/interface_tensor.pt with shape torch.Size([10166, 11])
# Loaded right tensor from ./data/training_dataset/old/right_tensor.pt with shape torch.Size([1545, 8])
# Loaded fluid_points tensor from ./data/training_dataset/old/fluid_points_tensor.pt with shape torch.Size([3986, 8])
# Loaded bottom tensor from ./data/training_dataset/old/bottom_tensor.pt with shape torch.Size([1030, 8])
# Loaded left tensor from ./data/training_dataset/old/left_tensor.pt with shape torch.Size([1030, 8])
# Loaded solid tensor from ./data/training_dataset/old/solid_tensor.pt with shape torch.Size([1452, 8])
# Loaded initial tensor from ./data/training_dataset/old/initial_tensor.pt with shape torch.Size([1330, 8])
# Loaded up tensor from ./data/training_dataset/old/up_tensor.pt with shape torch.Size([1030, 8])
# Loaded fluid tensor from ./data/training_dataset/old/fluid_tensor.pt with shape torch.Size([10508, 8])
# Loaded training dataset from ./data/training_dataset/old successfully!

# %%
visualize_tensor_datasets(training_data, save_dir=training_data_path)

fluid_network = (
    [config["input_dim"]] + [config["hidden_dim"]] * config["hidden_layers_dim"] + [3]
)
if config["solver"] == "mlp":
    fluid_model = MLP(network=fluid_network)
else:
    fluid_model = KAN(fluid_network)

logger.print("Fluid model architecture:")
logger.print(fluid_model)
logger.print(
    f"Number of parameters: {sum(p.numel() for p in fluid_model.parameters())}"
)
# Out:
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:KAN(
#   (layers): ModuleList(
#     (0-3): 4 x KANLinear(
#       (base_activation): SiLU()
#     )
#   )
# )
# INFO:src.utils.logger:Number of parameters: 206000
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png

# %%
trainer = PINNTrainer(
    fluid_model=fluid_model,
    training_data=training_data,
    learning_rate=config["learning_rate"],
    logger=logger,
    device=config["device"],
    fluid_density=config["fluid_density"],
    fluid_viscosity=config["fluid_viscosity"],
    print_every=config["print_every"],
    save_every=config["save_every"],
    solver=config["solver"],
    model=config["model"],
)


loss_history = trainer.train(
    num_epochs=config["num_epochs"],
    batch_size=config["batch_size"],
    data_weight=config["data_weight"],
    physics_weight=config["physics_weight"],
    boundary_weight=config["boundary_weight"],
    fsi_weight=config["fsi_weight"],
    initial_weight=config["initial_weight"],
)
# Out:
# INFO:src.utils.logger:Epoch 0/60000, Total: 1.1e+01, Data(F): 1.3e-01, Data(S): 7.6e-02, Physics: 1.5e-06, Boundary: 3.1e+00, FSI: 7.7e+00, Initial: 5.7e-04, LR: 1.00e-03
