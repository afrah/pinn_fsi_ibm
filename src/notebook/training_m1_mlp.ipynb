# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python -m src.trainer.m1_mlp_trainer
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-20_14-00-13-016168
# GPU memory cleared!
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 300
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 128
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.005
# INFO:src.utils.logger:boundary_weight: 4.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 1.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 1000
# INFO:src.utils.logger:save_every: 2000
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.05
# INFO:src.utils.logger:solid_sampling_ratio: 0.01
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.1
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.15
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cuda
# INFO:src.utils.logger:solver: mlp
# INFO:src.utils.logger:model: m1
# Saved fluid tensor with shape torch.Size([10508, 8]) to ./data/training_dataset/old/fluid_tensor.pt
# Saved fluid_points tensor with shape torch.Size([3986, 8]) to ./data/training_dataset/old/fluid_points_tensor.pt
# Saved interface tensor with shape torch.Size([7262, 11]) to ./data/training_dataset/old/interface_tensor.pt
# Saved solid tensor with shape torch.Size([1452, 8]) to ./data/training_dataset/old/solid_tensor.pt
# Saved left tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/left_tensor.pt
# Saved right tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/right_tensor.pt
# Saved bottom tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/bottom_tensor.pt
# Saved up tensor with shape torch.Size([1545, 8]) to ./data/training_dataset/old/up_tensor.pt
# Saved initial tensor with shape torch.Size([1330, 8]) to ./data/training_dataset/old/initial_tensor.pt
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=300, bias=True)
#     (1-2): 2 x Linear(in_features=300, out_features=300, bias=True)
#     (3): Linear(in_features=300, out_features=3, bias=True)
#   )
# )
# INFO:src.utils.logger:Number of parameters: 182703
# INFO:src.utils.logger:Epoch 0/60000, Total: 7.7e+00, Data(F): 3.0e-01, Data(S): 1.4e-01, Physics: 1.4e-03, Boundary: 7.2e+00, FSI: 3.3e-04, Initial: 5.4e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1000/60000, Total: 1.3e+00, Data(F): 5.5e-02, Data(S): 3.6e-02, Physics: 6.4e-03, Boundary: 1.2e+00, FSI: 2.9e-03, Initial: 2.4e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 6.657e-02 |  Final right: 4.544e-02 |  Final bottom: 5.765e-03 |  Final up: 2.609e-01 |  Final solid: 1.579e-02 |  Final fluid_points: 2.755e-02 |  Final fluid: 1.005e-02 |  Final interface: 7.416e-04 |  Final initial: 2.655e-02 |  Final total: 4.593e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 2000/60000, Total: 8.3e-01, Data(F): 4.6e-02, Data(S): 2.6e-02, Physics: 7.7e-03, Boundary: 7.2e-01, FSI: 1.9e-03, Initial: 2.5e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 3000/60000, Total: 3.8e-01, Data(F): 1.9e-02, Data(S): 1.6e-02, Physics: 7.4e-03, Boundary: 3.2e-01, FSI: 1.2e-03, Initial: 9.3e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 5.471e-02 |  Final right: 5.351e-02 |  Final bottom: 1.271e-02 |  Final up: 1.099e-01 |  Final solid: 1.705e-02 |  Final fluid_points: 2.748e-02 |  Final fluid: 1.355e-02 |  Final interface: 1.683e-03 |  Final initial: 1.439e-02 |  Final total: 3.050e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 4000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 4000/60000, Total: 3.0e-01, Data(F): 3.1e-02, Data(S): 1.2e-02, Physics: 7.9e-03, Boundary: 2.3e-01, FSI: 1.0e-03, Initial: 1.6e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 5000/60000, Total: 2.5e-01, Data(F): 1.7e-02, Data(S): 9.7e-03, Physics: 8.8e-03, Boundary: 2.0e-01, FSI: 1.9e-03, Initial: 1.6e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.216e-02 |  Final right: 1.750e-02 |  Final bottom: 3.825e-03 |  Final up: 9.648e-02 |  Final solid: 7.591e-03 |  Final fluid_points: 1.175e-02 |  Final fluid: 6.332e-03 |  Final interface: 3.670e-03 |  Final initial: 7.643e-03 |  Final total: 1.670e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 6000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 6000/60000, Total: 1.4e-01, Data(F): 9.5e-03, Data(S): 6.6e-03, Physics: 5.1e-02, Boundary: 6.4e-02, FSI: 3.0e-03, Initial: 7.3e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 7000/60000, Total: 2.0e-01, Data(F): 1.1e-02, Data(S): 7.8e-03, Physics: 1.7e-02, Boundary: 1.6e-01, FSI: 2.2e-03, Initial: 6.5e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.935e-02 |  Final right: 1.417e-02 |  Final bottom: 4.185e-03 |  Final up: 5.993e-02 |  Final solid: 7.738e-03 |  Final fluid_points: 7.386e-03 |  Final fluid: 1.766e-02 |  Final interface: 1.398e-03 |  Final initial: 8.605e-03 |  Final total: 1.404e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 8000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 8000/60000, Total: 1.6e-01, Data(F): 1.0e-02, Data(S): 1.0e-02, Physics: 1.0e-02, Boundary: 1.2e-01, FSI: 3.4e-03, Initial: 7.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 9000/60000, Total: 1.6e-01, Data(F): 1.3e-02, Data(S): 1.0e-02, Physics: 1.0e-02, Boundary: 1.2e-01, FSI: 2.3e-03, Initial: 3.5e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.237e-02 |  Final right: 9.878e-03 |  Final bottom: 1.361e-03 |  Final up: 4.570e-02 |  Final solid: 5.806e-03 |  Final fluid_points: 7.854e-03 |  Final fluid: 1.969e-02 |  Final interface: 2.118e-03 |  Final initial: 2.034e-03 |  Final total: 1.068e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 10000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 10000/60000, Total: 1.1e-01, Data(F): 7.8e-03, Data(S): 6.5e-03, Physics: 9.6e-03, Boundary: 7.8e-02, FSI: 1.6e-03, Initial: 5.0e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 11000/60000, Total: 1.5e-01, Data(F): 1.4e-02, Data(S): 9.8e-03, Physics: 4.0e-02, Boundary: 7.8e-02, FSI: 1.7e-03, Initial: 2.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 7.032e-03 |  Final right: 1.101e-02 |  Final bottom: 2.253e-03 |  Final up: 2.740e-02 |  Final solid: 8.204e-03 |  Final fluid_points: 1.345e-02 |  Final fluid: 3.794e-03 |  Final interface: 6.352e-03 |  Final initial: 3.979e-03 |  Final total: 8.348e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 12000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 12000/60000, Total: 9.7e-02, Data(F): 8.8e-03, Data(S): 9.2e-03, Physics: 5.7e-03, Boundary: 6.6e-02, FSI: 8.6e-04, Initial: 7.3e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 13000/60000, Total: 6.2e-02, Data(F): 6.3e-03, Data(S): 9.3e-03, Physics: 8.3e-03, Boundary: 3.6e-02, FSI: 1.4e-03, Initial: 8.1e-04, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.982e-02 |  Final right: 5.663e-03 |  Final bottom: 1.295e-03 |  Final up: 2.480e-02 |  Final solid: 6.164e-03 |  Final fluid_points: 6.014e-03 |  Final fluid: 4.645e-02 |  Final interface: 2.615e-03 |  Final initial: 1.652e-03 |  Final total: 1.145e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 14000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 14000/60000, Total: 8.1e-02, Data(F): 6.2e-03, Data(S): 5.8e-03, Physics: 1.5e-02, Boundary: 4.9e-02, FSI: 1.9e-03, Initial: 2.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 15000/60000, Total: 1.1e-01, Data(F): 6.2e-03, Data(S): 6.7e-03, Physics: 5.2e-02, Boundary: 3.2e-02, FSI: 8.1e-03, Initial: 2.0e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.197e-02 |  Final right: 9.559e-03 |  Final bottom: 1.094e-02 |  Final up: 4.438e-02 |  Final solid: 1.020e-02 |  Final fluid_points: 1.040e-02 |  Final fluid: 1.017e-02 |  Final interface: 1.003e-03 |  Final initial: 7.527e-03 |  Final total: 1.162e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 16000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 16000/60000, Total: 9.3e-02, Data(F): 7.8e-03, Data(S): 4.8e-03, Physics: 1.1e-02, Boundary: 6.5e-02, FSI: 2.3e-03, Initial: 2.3e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 17000/60000, Total: 7.2e-02, Data(F): 6.5e-03, Data(S): 7.2e-03, Physics: 2.6e-02, Boundary: 3.0e-02, FSI: 1.7e-03, Initial: 5.8e-04, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 7.116e-03 |  Final right: 1.172e-02 |  Final bottom: 9.202e-04 |  Final up: 2.240e-02 |  Final solid: 8.170e-03 |  Final fluid_points: 6.780e-03 |  Final fluid: 4.771e-03 |  Final interface: 3.381e-03 |  Final initial: 6.852e-04 |  Final total: 6.594e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 18000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 18000/60000, Total: 8.0e-02, Data(F): 8.1e-03, Data(S): 5.1e-03, Physics: 1.8e-02, Boundary: 4.7e-02, FSI: 6.6e-04, Initial: 1.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 19000/60000, Total: 1.3e-01, Data(F): 4.8e-03, Data(S): 7.3e-03, Physics: 1.3e-02, Boundary: 9.8e-02, FSI: 2.4e-03, Initial: 3.4e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 9.258e-03 |  Final right: 2.926e-03 |  Final bottom: 7.311e-04 |  Final up: 1.147e-02 |  Final solid: 4.884e-03 |  Final fluid_points: 1.117e-02 |  Final fluid: 4.535e-02 |  Final interface: 2.041e-03 |  Final initial: 8.334e-04 |  Final total: 8.867e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 20000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 20000/60000, Total: 7.8e-02, Data(F): 7.9e-03, Data(S): 3.4e-03, Physics: 1.0e-02, Boundary: 5.5e-02, FSI: 1.3e-03, Initial: 5.8e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 21000/60000, Total: 6.9e-02, Data(F): 5.8e-03, Data(S): 1.1e-02, Physics: 1.5e-02, Boundary: 3.6e-02, FSI: 3.8e-04, Initial: 1.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 6.120e-03 |  Final right: 1.662e-02 |  Final bottom: 2.580e-03 |  Final up: 8.956e-03 |  Final solid: 6.428e-03 |  Final fluid_points: 4.624e-03 |  Final fluid: 2.083e-02 |  Final interface: 3.625e-03 |  Final initial: 1.575e-03 |  Final total: 7.136e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 22000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 22000/60000, Total: 9.4e-02, Data(F): 7.5e-03, Data(S): 5.5e-03, Physics: 4.5e-02, Boundary: 3.1e-02, FSI: 5.6e-04, Initial: 3.9e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 23000/60000, Total: 7.4e-02, Data(F): 5.6e-03, Data(S): 4.1e-03, Physics: 2.3e-02, Boundary: 3.9e-02, FSI: 1.6e-03, Initial: 1.5e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 7.801e-03 |  Final right: 1.114e-02 |  Final bottom: 3.249e-03 |  Final up: 1.177e-02 |  Final solid: 5.496e-03 |  Final fluid_points: 1.064e-02 |  Final fluid: 1.172e-02 |  Final interface: 1.399e-03 |  Final initial: 2.559e-03 |  Final total: 6.578e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 24000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 24000/60000, Total: 7.8e-02, Data(F): 5.8e-03, Data(S): 7.4e-03, Physics: 1.9e-02, Boundary: 4.4e-02, FSI: 2.1e-03, Initial: 4.6e-04, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 25000/60000, Total: 5.6e-02, Data(F): 5.7e-03, Data(S): 6.1e-03, Physics: 4.2e-03, Boundary: 3.6e-02, FSI: 1.8e-03, Initial: 2.7e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 6.253e-03 |  Final right: 5.776e-03 |  Final bottom: 1.796e-03 |  Final up: 2.244e-02 |  Final solid: 3.730e-03 |  Final fluid_points: 6.868e-03 |  Final fluid: 1.790e-02 |  Final interface: 1.798e-03 |  Final initial: 2.696e-03 |  Final total: 6.925e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 26000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 26000/60000, Total: 5.6e-02, Data(F): 6.3e-03, Data(S): 7.6e-03, Physics: 5.0e-03, Boundary: 3.3e-02, FSI: 2.9e-03, Initial: 1.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 27000/60000, Total: 3.5e-02, Data(F): 5.2e-03, Data(S): 9.1e-03, Physics: 4.2e-03, Boundary: 1.5e-02, FSI: 9.6e-04, Initial: 1.2e-03, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.161e-03 |  Final right: 6.141e-03 |  Final bottom: 1.065e-03 |  Final up: 2.424e-02 |  Final solid: 4.984e-03 |  Final fluid_points: 6.324e-03 |  Final fluid: 1.058e-02 |  Final interface: 1.590e-03 |  Final initial: 8.749e-04 |  Final total: 5.796e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 28000 | Training checkpoint saved at ./checkpoints/2025-08-20_14-00-13-016168/model.pth
# INFO:src.utils.logger:Epoch 28000/60000, Total: 4.9e-02, Data(F): 5.0e-03, Data(S): 4.6e-03, Physics: 8.8e-03, Boundary: 2.6e-02, FSI: 1.6e-03, Initial: 3.1e-03, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 29000/60000, Total: 4.8e-02, Data(F): 6.0e-03, Data(S): 3.6e-03, Physics: 7.4e-03, Boundary: 2.9e-02, FSI: 1.3e-03, Initial: 9.8e-04, LR: 1.00e-03

# %%
import torch
from src.utils.utils import lp_error
from src.utils.logger import Logging
from src.utils.colors import model_color

from src.nn.tanh import MLP
from src.nn.bspline import KAN
from src.utils.utils import clear_gpu_memory
from src.data.IBM_data_loader import prepare_training_data, visualize_tensor_datasets
from src.data.IBM_data_loader import load_fluid_testing_dataset
from src.models.m1_physics import PINNTrainer
from src.utils.plot_losses import plot_M1_loss_history
from src.utils.fsi_visualization import (
    create_frames,
    create_animations_from_existing_frames,
)
from src.data.IBM_data_loader import load_training_dataset

# %%
CHECKPOINT_PATH = "./checkpoints"
logger = Logging(CHECKPOINT_PATH)
model_dirname = logger.get_output_dir()

logger.print(model_dirname)
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-18_13-51-53-682395

# %%
clear_gpu_memory()
config = {
    "dataset_type": "old",
    "training_selection_method": "Sobol",
    "input_dim": 3,  # (x, y, z, t)
    "hidden_dim": 100,
    "hidden_layers_dim": 3,
    "fluid_density": 1.0,
    "fluid_viscosity": 0.01,
    "num_epochs": 60000,
    "batch_size": 128,
    "learning_rate": 1e-3,
    "data_weight": 2.0,
    "physics_weight": 0.01,
    "boundary_weight": 2.0,
    "fsi_weight": 0.5,
    "initial_weight": 4.0,
    "checkpoint_dir": "./checkpoints",
    "resume": None,
    "print_every": 100,
    "save_every": 200,
    "fluid_sampling_ratio": 0.01,
    "interface_sampling_ratio": 0.07,
    "solid_sampling_ratio": 0.0,
    "left_sampling_ratio": 0.1,
    "right_sampling_ratio": 0.15,
    "bottom_sampling_ratio": 0.1,
    "top_sampling_ratio": 0.1,
    "initial_sampling_ratio": 0.1,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    "solver": "kan",
    "model": "m1",
}
# Out:
# GPU memory cleared!

# %%
logger.print("Config:")
for key, value in config.items():
    logger.print(f"{key}: {value}")

training_data_path = "./data/training_dataset/old"

training_data = load_training_dataset(training_data_path, device=config["device"])

if training_data is None:
    training_data = prepare_training_data(
        config["dataset_type"],
        fluid_sampling_ratio=config["fluid_sampling_ratio"],
        interface_sampling_ratio=config["interface_sampling_ratio"],
        solid_sampling_ratio=config["solid_sampling_ratio"],
        left_sampling_ratio=config["left_sampling_ratio"],
        right_sampling_ratio=config["right_sampling_ratio"],
        bottom_sampling_ratio=config["bottom_sampling_ratio"],
        top_sampling_ratio=config["top_sampling_ratio"],
        initial_sampling_ratio=config["initial_sampling_ratio"],
        training_selection_method=config["training_selection_method"],
        device=config["device"],
        save_dir=training_data_path,
    )
# Out:
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 100
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 128
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.01
# INFO:src.utils.logger:boundary_weight: 2.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 4.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 100
# INFO:src.utils.logger:save_every: 200
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.07
# INFO:src.utils.logger:solid_sampling_ratio: 0.0
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.15
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.1
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cpu
# INFO:src.utils.logger:solver: kan
# INFO:src.utils.logger:model: m1
# Loaded interface tensor from ./data/training_dataset/old/interface_tensor.pt with shape torch.Size([10166, 11])
# Loaded right tensor from ./data/training_dataset/old/right_tensor.pt with shape torch.Size([1545, 8])
# Loaded fluid_points tensor from ./data/training_dataset/old/fluid_points_tensor.pt with shape torch.Size([3986, 8])
# Loaded bottom tensor from ./data/training_dataset/old/bottom_tensor.pt with shape torch.Size([1030, 8])
# Loaded left tensor from ./data/training_dataset/old/left_tensor.pt with shape torch.Size([1030, 8])
# Loaded solid tensor from ./data/training_dataset/old/solid_tensor.pt with shape torch.Size([1452, 8])
# Loaded initial tensor from ./data/training_dataset/old/initial_tensor.pt with shape torch.Size([1330, 8])
# Loaded up tensor from ./data/training_dataset/old/up_tensor.pt with shape torch.Size([1030, 8])
# Loaded fluid tensor from ./data/training_dataset/old/fluid_tensor.pt with shape torch.Size([10508, 8])
# Loaded training dataset from ./data/training_dataset/old successfully!

# %%
visualize_tensor_datasets(training_data, save_dir=training_data_path)

fluid_network = (
    [config["input_dim"]] + [config["hidden_dim"]] * config["hidden_layers_dim"] + [3]
)
if config["solver"] == "mlp":
    fluid_model = MLP(network=fluid_network)
else:
    fluid_model = KAN(fluid_network)

logger.print("Fluid model architecture:")
logger.print(fluid_model)
logger.print(
    f"Number of parameters: {sum(p.numel() for p in fluid_model.parameters())}"
)
# Out:
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:KAN(
#   (layers): ModuleList(
#     (0-3): 4 x KANLinear(
#       (base_activation): SiLU()
#     )
#   )
# )
# INFO:src.utils.logger:Number of parameters: 206000
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png

# %%
trainer = PINNTrainer(
    fluid_model=fluid_model,
    training_data=training_data,
    learning_rate=config["learning_rate"],
    logger=logger,
    device=config["device"],
    fluid_density=config["fluid_density"],
    fluid_viscosity=config["fluid_viscosity"],
    print_every=config["print_every"],
    save_every=config["save_every"],
    solver=config["solver"],
    model=config["model"],
)


loss_history = trainer.train(
    num_epochs=config["num_epochs"],
    batch_size=config["batch_size"],
    data_weight=config["data_weight"],
    physics_weight=config["physics_weight"],
    boundary_weight=config["boundary_weight"],
    fsi_weight=config["fsi_weight"],
    initial_weight=config["initial_weight"],
)
# Out:
# INFO:src.utils.logger:Epoch 0/60000, Total: 1.1e+01, Data(F): 1.3e-01, Data(S): 7.6e-02, Physics: 1.5e-06, Boundary: 3.1e+00, FSI: 7.7e+00, Initial: 5.7e-04, LR: 1.00e-03
