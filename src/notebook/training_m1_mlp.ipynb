# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python -m src.trainer.m1_mlp_trainer_pressure
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-20_01-59-01-525334
# GPU memory cleared!
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 300
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 128
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.01
# INFO:src.utils.logger:boundary_weight: 2.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 4.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 1000
# INFO:src.utils.logger:save_every: 2000
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.07
# INFO:src.utils.logger:solid_sampling_ratio: 0.01
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.1
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.15
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cuda
# INFO:src.utils.logger:solver: mlp
# INFO:src.utils.logger:model: m1
# Saved fluid tensor with shape torch.Size([10508, 8]) to ./data/training_dataset/old/fluid_tensor.pt
# Saved fluid_points tensor with shape torch.Size([3986, 8]) to ./data/training_dataset/old/fluid_points_tensor.pt
# Saved interface tensor with shape torch.Size([10166, 11]) to ./data/training_dataset/old/interface_tensor.pt
# Saved solid tensor with shape torch.Size([1452, 8]) to ./data/training_dataset/old/solid_tensor.pt
# Saved left tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/left_tensor.pt
# Saved right tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/right_tensor.pt
# Saved bottom tensor with shape torch.Size([1030, 8]) to ./data/training_dataset/old/bottom_tensor.pt
# Saved up tensor with shape torch.Size([1545, 8]) to ./data/training_dataset/old/up_tensor.pt
# Saved initial tensor with shape torch.Size([1330, 8]) to ./data/training_dataset/old/initial_tensor.pt
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=300, bias=True)
#     (1-2): 2 x Linear(in_features=300, out_features=300, bias=True)
#     (3): Linear(in_features=300, out_features=3, bias=True)
#   )
# )
# INFO:src.utils.logger:Number of parameters: 182703
# INFO:src.utils.logger:Epoch 0/60000, Total: 4.6e+00, Data(F): 2.2e-01, Data(S): 7.7e-03, Physics: 1.8e-03, Boundary: 3.4e+00, FSI: 8.3e-01, Initial: 1.8e-01, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1000/60000, Total: 3.4e-01, Data(F): 5.7e-02, Data(S): 7.2e-03, Physics: 1.9e-03, Boundary: 1.8e-01, FSI: 4.9e-02, Initial: 3.8e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 7.428e-03 |  Final right: 2.107e-02 |  Final bottom: 1.740e-03 |  Final up: 6.024e-02 |  Final fluid: 3.454e-03 |  Final interface: 1.644e-02 |  Final initial: 3.907e-03 |  Final total: 1.559e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 2000/60000, Total: 1.9e-01, Data(F): 3.6e-02, Data(S): 3.9e-03, Physics: 4.3e-03, Boundary: 7.2e-02, FSI: 3.7e-02, Initial: 3.7e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 3000/60000, Total: 1.9e-01, Data(F): 2.8e-02, Data(S): 4.8e-03, Physics: 1.4e-02, Boundary: 7.6e-02, FSI: 3.2e-02, Initial: 3.2e-02, LR: 8.50e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.307e-02 |  Final right: 1.753e-02 |  Final bottom: 3.701e-04 |  Final up: 1.077e-02 |  Final fluid: 9.641e-03 |  Final interface: 1.248e-02 |  Final initial: 1.657e-03 |  Final total: 1.254e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 4000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 4000/60000, Total: 1.5e-01, Data(F): 1.7e-02, Data(S): 6.5e-02, Physics: 9.9e-03, Boundary: 3.8e-02, FSI: 1.0e-02, Initial: 1.1e-02, LR: 8.50e-04
# INFO:src.utils.logger:Epoch 5000/60000, Total: 1.2e-01, Data(F): 2.8e-02, Data(S): 8.5e-03, Physics: 8.6e-03, Boundary: 4.7e-02, FSI: 1.8e-02, Initial: 1.1e-02, LR: 7.22e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 6.076e-04 |  Final right: 9.758e-04 |  Final bottom: 1.516e-04 |  Final up: 9.725e-03 |  Final fluid: 7.081e-03 |  Final interface: 1.461e-02 |  Final initial: 1.800e-02 |  Final total: 7.882e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 6000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 6000/60000, Total: 1.7e-01, Data(F): 2.0e-02, Data(S): 6.9e-02, Physics: 8.5e-03, Boundary: 3.8e-02, FSI: 1.9e-02, Initial: 1.4e-02, LR: 5.22e-04
# INFO:src.utils.logger:Epoch 7000/60000, Total: 1.2e-01, Data(F): 2.1e-02, Data(S): 7.7e-03, Physics: 6.0e-03, Boundary: 4.1e-02, FSI: 3.3e-02, Initial: 8.8e-03, LR: 4.44e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 5.128e-03 |  Final right: 5.696e-03 |  Final bottom: 2.247e-04 |  Final up: 1.576e-02 |  Final fluid: 6.283e-03 |  Final interface: 8.211e-03 |  Final initial: 2.656e-03 |  Final total: 7.311e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 8000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 8000/60000, Total: 1.2e-01, Data(F): 2.8e-02, Data(S): 6.2e-03, Physics: 8.6e-03, Boundary: 5.9e-02, FSI: 1.7e-02, Initial: 3.8e-03, LR: 4.44e-04
# INFO:src.utils.logger:Epoch 9000/60000, Total: 9.7e-02, Data(F): 1.6e-02, Data(S): 7.8e-03, Physics: 4.1e-03, Boundary: 4.3e-02, FSI: 1.1e-02, Initial: 1.5e-02, LR: 3.77e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.672e-03 |  Final right: 8.929e-03 |  Final bottom: 1.836e-04 |  Final up: 3.079e-02 |  Final fluid: 8.847e-03 |  Final interface: 1.350e-02 |  Final initial: 1.957e-03 |  Final total: 1.168e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 10000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 10000/60000, Total: 1.1e-01, Data(F): 1.8e-02, Data(S): 4.3e-03, Physics: 9.3e-03, Boundary: 2.7e-02, FSI: 5.2e-02, Initial: 3.0e-03, LR: 2.72e-04
# INFO:src.utils.logger:Epoch 11000/60000, Total: 1.0e-01, Data(F): 3.0e-02, Data(S): 5.7e-03, Physics: 1.2e-02, Boundary: 3.9e-02, FSI: 1.1e-02, Initial: 6.3e-03, LR: 1.97e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.695e-02 |  Final right: 1.850e-02 |  Final bottom: 1.484e-04 |  Final up: 1.808e-02 |  Final fluid: 1.712e-02 |  Final interface: 9.259e-03 |  Final initial: 1.862e-03 |  Final total: 1.139e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 12000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 12000/60000, Total: 6.4e-02, Data(F): 1.2e-02, Data(S): 6.9e-03, Physics: 9.7e-03, Boundary: 2.5e-02, FSI: 7.6e-03, Initial: 2.7e-03, LR: 1.42e-04
# INFO:src.utils.logger:Epoch 13000/60000, Total: 7.1e-02, Data(F): 1.7e-02, Data(S): 4.8e-03, Physics: 1.8e-02, Boundary: 2.2e-02, FSI: 7.4e-03, Initial: 3.0e-03, LR: 1.21e-04
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 4.259e-04 |  Final right: 1.195e-02 |  Final bottom: 6.127e-05 |  Final up: 2.525e-02 |  Final fluid: 1.640e-02 |  Final interface: 8.863e-03 |  Final initial: 6.633e-03 |  Final total: 9.930e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 14000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 14000/60000, Total: 4.6e-02, Data(F): 1.2e-02, Data(S): 8.3e-03, Physics: 5.6e-03, Boundary: 1.6e-02, FSI: 3.1e-03, Initial: 9.2e-04, LR: 8.74e-05
# INFO:src.utils.logger:Epoch 15000/60000, Total: 7.6e-02, Data(F): 1.3e-02, Data(S): 7.3e-03, Physics: 1.2e-02, Boundary: 3.2e-02, FSI: 1.1e-02, Initial: 9.4e-04, LR: 7.43e-05
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.901e-03 |  Final right: 8.283e-03 |  Final bottom: 1.298e-04 |  Final up: 1.330e-02 |  Final fluid: 1.063e-02 |  Final interface: 9.370e-03 |  Final initial: 4.018e-04 |  Final total: 1.015e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 16000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 16000/60000, Total: 5.6e-02, Data(F): 1.2e-02, Data(S): 5.2e-03, Physics: 8.4e-03, Boundary: 2.0e-02, FSI: 7.8e-03, Initial: 3.7e-03, LR: 5.36e-05
# INFO:src.utils.logger:Epoch 17000/60000, Total: 8.8e-02, Data(F): 1.1e-02, Data(S): 5.5e-03, Physics: 4.3e-03, Boundary: 4.5e-02, FSI: 6.5e-03, Initial: 1.5e-02, LR: 3.88e-05
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 9.084e-03 |  Final right: 8.523e-03 |  Final bottom: 7.350e-05 |  Final up: 5.135e-03 |  Final fluid: 1.665e-02 |  Final interface: 9.318e-03 |  Final initial: 3.272e-04 |  Final total: 7.408e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 18000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 18000/60000, Total: 1.5e-01, Data(F): 8.1e-02, Data(S): 6.0e-03, Physics: 1.5e-02, Boundary: 3.3e-02, FSI: 1.5e-02, Initial: 3.8e-04, LR: 2.80e-05
# INFO:src.utils.logger:Epoch 19000/60000, Total: 7.0e-02, Data(F): 1.2e-02, Data(S): 7.9e-03, Physics: 2.1e-02, Boundary: 2.1e-02, FSI: 7.2e-03, Initial: 1.4e-03, LR: 2.02e-05
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.614e-03 |  Final right: 1.164e-02 |  Final bottom: 4.660e-05 |  Final up: 5.818e-03 |  Final fluid: 1.443e-02 |  Final interface: 6.114e-03 |  Final initial: 5.484e-04 |  Final total: 5.424e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 20000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 20000/60000, Total: 7.8e-02, Data(F): 2.5e-02, Data(S): 4.3e-03, Physics: 1.0e-02, Boundary: 2.7e-02, FSI: 1.2e-02, Initial: 5.1e-04, LR: 1.46e-05
# INFO:src.utils.logger:Epoch 21000/60000, Total: 6.0e-02, Data(F): 1.1e-02, Data(S): 4.1e-03, Physics: 9.5e-03, Boundary: 2.9e-02, FSI: 5.0e-03, Initial: 1.2e-03, LR: 1.06e-05
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.131e-02 |  Final right: 7.945e-03 |  Final bottom: 4.904e-05 |  Final up: 4.594e-03 |  Final fluid: 1.959e-02 |  Final interface: 6.585e-03 |  Final initial: 2.684e-04 |  Final total: 7.110e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 22000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 22000/60000, Total: 1.0e-01, Data(F): 1.3e-02, Data(S): 8.0e-03, Physics: 6.0e-03, Boundary: 6.9e-02, FSI: 7.0e-03, Initial: 2.0e-03, LR: 7.63e-06
# INFO:src.utils.logger:Epoch 23000/60000, Total: 7.4e-02, Data(F): 9.9e-03, Data(S): 2.8e-02, Physics: 1.3e-02, Boundary: 1.2e-02, FSI: 9.6e-03, Initial: 1.3e-03, LR: 5.51e-06
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.599e-02 |  Final right: 8.935e-03 |  Final bottom: 4.162e-05 |  Final up: 1.794e-02 |  Final fluid: 1.380e-02 |  Final interface: 3.573e-03 |  Final initial: 1.672e-02 |  Final total: 1.019e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 24000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 24000/60000, Total: 8.7e-02, Data(F): 7.3e-03, Data(S): 5.0e-03, Physics: 1.3e-02, Boundary: 3.0e-02, FSI: 1.3e-02, Initial: 1.9e-02, LR: 3.98e-06
# INFO:src.utils.logger:Epoch 25000/60000, Total: 4.0e-02, Data(F): 1.1e-02, Data(S): 6.7e-03, Physics: 6.6e-03, Boundary: 1.0e-02, FSI: 4.0e-03, Initial: 1.1e-03, LR: 2.88e-06
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 8.835e-03 |  Final right: 3.811e-04 |  Final bottom: 4.670e-05 |  Final up: 1.310e-02 |  Final fluid: 2.086e-02 |  Final interface: 2.797e-02 |  Final initial: 3.175e-04 |  Final total: 9.198e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 26000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 26000/60000, Total: 5.7e-02, Data(F): 1.2e-02, Data(S): 8.8e-03, Physics: 1.8e-02, Boundary: 1.1e-02, FSI: 7.4e-03, Initial: 2.8e-04, LR: 2.08e-06
# INFO:src.utils.logger:Epoch 27000/60000, Total: 5.8e-02, Data(F): 1.1e-02, Data(S): 8.2e-03, Physics: 9.4e-03, Boundary: 1.6e-02, FSI: 6.3e-03, Initial: 7.4e-03, LR: 1.50e-06
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 7.839e-03 |  Final right: 1.001e-02 |  Final bottom: 4.238e-05 |  Final up: 9.721e-03 |  Final fluid: 9.418e-03 |  Final interface: 1.666e-02 |  Final initial: 1.426e-03 |  Final total: 1.145e-01 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 28000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 28000/60000, Total: 8.0e-02, Data(F): 9.7e-03, Data(S): 8.0e-03, Physics: 1.1e-02, Boundary: 3.8e-02, FSI: 5.2e-03, Initial: 8.6e-03, LR: 1.09e-06
# INFO:src.utils.logger:Epoch 29000/60000, Total: 8.1e-02, Data(F): 1.4e-02, Data(S): 4.9e-03, Physics: 1.7e-02, Boundary: 4.0e-02, FSI: 4.5e-03, Initial: 3.7e-04, LR: 7.84e-07
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 6.914e-04 |  Final right: 7.362e-03 |  Final bottom: 4.810e-05 |  Final up: 9.441e-03 |  Final fluid: 1.523e-02 |  Final interface: 9.222e-03 |  Final initial: 5.018e-04 |  Final total: 5.600e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 30000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Epoch 30000/60000, Total: 6.6e-02, Data(F): 1.1e-02, Data(S): 5.6e-03, Physics: 6.2e-03, Boundary: 3.7e-02, FSI: 5.7e-03, Initial: 6.5e-04, LR: 5.67e-07
# INFO:src.utils.logger:Epoch 31000/60000, Total: 7.4e-02, Data(F): 1.5e-02, Data(S): 7.9e-03, Physics: 1.7e-02, Boundary: 7.6e-03, FSI: 2.5e-02, Initial: 2.6e-04, LR: 4.09e-07
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.368e-03 |  Final right: 5.332e-04 |  Final bottom: 3.879e-05 |  Final up: 3.537e-03 |  Final fluid: 9.576e-03 |  Final interface: 2.446e-03 |  Final initial: 8.103e-03 |  Final total: 4.617e-02 |
# INFO:src.utils.logger:_save_checkpoint: Epoch
|
# INFO:src.utils.logger:_save_checkpoint: Epoch 60000 | Training checkpoint saved at ./checkpoints/2025-08-20_01-59-01-525334/model.pth
# INFO:src.utils.logger:Number of parameters: 182703
# final loss BC: 2.58e-02
# Warning: Loss history for Data is empty.
# Warning: Loss history for Fluid points is empty.
# final loss Physics: 6.21e-03
# final loss FSI: 2.38e-03
# final loss Initial: 6.49e-03
# /home/afrah/ubuntu/afrah/code/pinn_fsi_ibm/src/utils/plot_losses.py:139: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(bottom=y_min)
# Figure(1200x800)
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/afrah/ubuntu/afrah/code/pinn_fsi_ibm/src/trainer/m1_mlp_trainer_pressure.py", line 186, in <module>
#     outputs = fluid_model(torch.cat([time, x, y], dim=1).squeeze(1))
#   File "/home/afrah/miniconda3/envs/pinn-fsi-ibm/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/afrah/miniconda3/envs/pinn-fsi-ibm/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/afrah/ubuntu/afrah/code/pinn_fsi_ibm/src/nn/tanh.py", line 35, in forward
#     input = self.layers[index](input)
#   File "/home/afrah/miniconda3/envs/pinn-fsi-ibm/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/afrah/miniconda3/envs/pinn-fsi-ibm/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/afrah/miniconda3/envs/pinn-fsi-ibm/lib/python3.13/site-packages/torch/nn/modules/linear.py", line 125, in forward
#     return F.linear(input, self.weight, self.bias)
#            ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat1 in method wrapper_CUDA_addmm)

# %%
import torch
from src.utils.utils import lp_error
from src.utils.logger import Logging
from src.utils.colors import model_color

from src.nn.tanh import MLP
from src.nn.bspline import KAN
from src.utils.utils import clear_gpu_memory
from src.data.IBM_data_loader import prepare_training_data, visualize_tensor_datasets
from src.data.IBM_data_loader import load_fluid_testing_dataset
from src.models.m1_physics import PINNTrainer
from src.utils.plot_losses import plot_M1_loss_history
from src.utils.fsi_visualization import (
    create_frames,
    create_animations_from_existing_frames,
)
from src.data.IBM_data_loader import load_training_dataset

# %%
CHECKPOINT_PATH = "./checkpoints"
logger = Logging(CHECKPOINT_PATH)
model_dirname = logger.get_output_dir()

logger.print(model_dirname)
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-18_13-51-53-682395

# %%
clear_gpu_memory()
config = {
    "dataset_type": "old",
    "training_selection_method": "Sobol",
    "input_dim": 3,  # (x, y, z, t)
    "hidden_dim": 100,
    "hidden_layers_dim": 3,
    "fluid_density": 1.0,
    "fluid_viscosity": 0.01,
    "num_epochs": 60000,
    "batch_size": 128,
    "learning_rate": 1e-3,
    "data_weight": 2.0,
    "physics_weight": 0.01,
    "boundary_weight": 2.0,
    "fsi_weight": 0.5,
    "initial_weight": 4.0,
    "checkpoint_dir": "./checkpoints",
    "resume": None,
    "print_every": 100,
    "save_every": 200,
    "fluid_sampling_ratio": 0.01,
    "interface_sampling_ratio": 0.07,
    "solid_sampling_ratio": 0.0,
    "left_sampling_ratio": 0.1,
    "right_sampling_ratio": 0.15,
    "bottom_sampling_ratio": 0.1,
    "top_sampling_ratio": 0.1,
    "initial_sampling_ratio": 0.1,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    "solver": "kan",
    "model": "m1",
}
# Out:
# GPU memory cleared!

# %%
logger.print("Config:")
for key, value in config.items():
    logger.print(f"{key}: {value}")

training_data_path = "./data/training_dataset/old"

training_data = load_training_dataset(training_data_path, device=config["device"])

if training_data is None:
    training_data = prepare_training_data(
        config["dataset_type"],
        fluid_sampling_ratio=config["fluid_sampling_ratio"],
        interface_sampling_ratio=config["interface_sampling_ratio"],
        solid_sampling_ratio=config["solid_sampling_ratio"],
        left_sampling_ratio=config["left_sampling_ratio"],
        right_sampling_ratio=config["right_sampling_ratio"],
        bottom_sampling_ratio=config["bottom_sampling_ratio"],
        top_sampling_ratio=config["top_sampling_ratio"],
        initial_sampling_ratio=config["initial_sampling_ratio"],
        training_selection_method=config["training_selection_method"],
        device=config["device"],
        save_dir=training_data_path,
    )
# Out:
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 100
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 128
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.01
# INFO:src.utils.logger:boundary_weight: 2.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 4.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 100
# INFO:src.utils.logger:save_every: 200
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.07
# INFO:src.utils.logger:solid_sampling_ratio: 0.0
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.15
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.1
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cpu
# INFO:src.utils.logger:solver: kan
# INFO:src.utils.logger:model: m1
# Loaded interface tensor from ./data/training_dataset/old/interface_tensor.pt with shape torch.Size([10166, 11])
# Loaded right tensor from ./data/training_dataset/old/right_tensor.pt with shape torch.Size([1545, 8])
# Loaded fluid_points tensor from ./data/training_dataset/old/fluid_points_tensor.pt with shape torch.Size([3986, 8])
# Loaded bottom tensor from ./data/training_dataset/old/bottom_tensor.pt with shape torch.Size([1030, 8])
# Loaded left tensor from ./data/training_dataset/old/left_tensor.pt with shape torch.Size([1030, 8])
# Loaded solid tensor from ./data/training_dataset/old/solid_tensor.pt with shape torch.Size([1452, 8])
# Loaded initial tensor from ./data/training_dataset/old/initial_tensor.pt with shape torch.Size([1330, 8])
# Loaded up tensor from ./data/training_dataset/old/up_tensor.pt with shape torch.Size([1030, 8])
# Loaded fluid tensor from ./data/training_dataset/old/fluid_tensor.pt with shape torch.Size([10508, 8])
# Loaded training dataset from ./data/training_dataset/old successfully!

# %%
visualize_tensor_datasets(training_data, save_dir=training_data_path)

fluid_network = (
    [config["input_dim"]] + [config["hidden_dim"]] * config["hidden_layers_dim"] + [3]
)
if config["solver"] == "mlp":
    fluid_model = MLP(network=fluid_network)
else:
    fluid_model = KAN(fluid_network)

logger.print("Fluid model architecture:")
logger.print(fluid_model)
logger.print(
    f"Number of parameters: {sum(p.numel() for p in fluid_model.parameters())}"
)
# Out:
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:KAN(
#   (layers): ModuleList(
#     (0-3): 4 x KANLinear(
#       (base_activation): SiLU()
#     )
#   )
# )
# INFO:src.utils.logger:Number of parameters: 206000
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png

# %%
trainer = PINNTrainer(
    fluid_model=fluid_model,
    training_data=training_data,
    learning_rate=config["learning_rate"],
    logger=logger,
    device=config["device"],
    fluid_density=config["fluid_density"],
    fluid_viscosity=config["fluid_viscosity"],
    print_every=config["print_every"],
    save_every=config["save_every"],
    solver=config["solver"],
    model=config["model"],
)


loss_history = trainer.train(
    num_epochs=config["num_epochs"],
    batch_size=config["batch_size"],
    data_weight=config["data_weight"],
    physics_weight=config["physics_weight"],
    boundary_weight=config["boundary_weight"],
    fsi_weight=config["fsi_weight"],
    initial_weight=config["initial_weight"],
)
# Out:
# INFO:src.utils.logger:Epoch 0/60000, Total: 1.1e+01, Data(F): 1.3e-01, Data(S): 7.6e-02, Physics: 1.5e-06, Boundary: 3.1e+00, FSI: 7.7e+00, Initial: 5.7e-04, LR: 1.00e-03
