# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch



from src.utils.utils import lp_error
from src.utils.logger import Logging
from src.utils.colors import model_color

from src.nn.tanh2 import MLP2
from src.nn.tanh import MLP
from src.nn.bspline import KAN
from src.nn.kan2 import KAN2
from src.utils.utils import clear_gpu_memory
from src.data.IBM_data_loader import prepare_training_data, visualize_tensor_datasets
from src.data.IBM_data_loader import load_fluid_testing_dataset
from src.models.m2_physics2 import PINNTrainer
from src.utils.plot_losses import plot_M1_loss_history
from src.utils.fsi_visualization import (
    create_frames,
    create_animations_from_existing_frames,
)
from src.data.IBM_data_loader import load_training_dataset

# %%
CHECKPOINT_PATH = "./checkpoints"
logger = Logging(CHECKPOINT_PATH)
model_dirname = logger.get_output_dir()

logger.print(model_dirname)
# Out:
# INFO:src.utils.logger:./checkpoints/2025-08-17_22-11-00-832766

# %%
clear_gpu_memory()
config = {
    "dataset_type": "old",
    "training_selection_method": "Sobol",
    "input_dim": 3,  # (x, y, z, t)
    "hidden_dim": 50,
    "hidden_layers_dim": 3,
    "fluid_density": 1.0,
    "fluid_viscosity": 0.01,
    "num_epochs": 60000,
    "batch_size": 128,
    "learning_rate": 1e-3,
    "data_weight": 2.0,
    "physics_weight": 0.01,
    "boundary_weight": 2.0,
    "fsi_weight": 0.5,
    "initial_weight": 4.0,
    "checkpoint_dir": "./checkpoints",
    "resume": None,
    "print_every": 100,
    "save_every": 200,
    "fluid_sampling_ratio": 0.01,
    "interface_sampling_ratio": 0.07,
    "solid_sampling_ratio": 0.0,
    "left_sampling_ratio": 0.1,
    "right_sampling_ratio": 0.15,
    "bottom_sampling_ratio": 0.1,
    "top_sampling_ratio": 0.1,
    "initial_sampling_ratio": 0.1,
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    "solver": "mlp",
    "model": "m1",
}
# Out:
# GPU memory cleared!

# %%
logger.print("Config:")
for key, value in config.items():
    logger.print(f"{key}: {value}")

training_data_path = "./data/training_dataset/old"

training_data = load_training_dataset(training_data_path, device=config["device"])

if training_data is None:
    training_data = prepare_training_data(
        config["dataset_type"],
        fluid_sampling_ratio=config["fluid_sampling_ratio"],
        interface_sampling_ratio=config["interface_sampling_ratio"],
        solid_sampling_ratio=config["solid_sampling_ratio"],
        left_sampling_ratio=config["left_sampling_ratio"],
        right_sampling_ratio=config["right_sampling_ratio"],
        bottom_sampling_ratio=config["bottom_sampling_ratio"],
        top_sampling_ratio=config["top_sampling_ratio"],
        initial_sampling_ratio=config["initial_sampling_ratio"],
        training_selection_method=config["training_selection_method"],
        device=config["device"],
        save_dir=training_data_path,
    )
# Out:
# INFO:src.utils.logger:Config:
# INFO:src.utils.logger:dataset_type: old
# INFO:src.utils.logger:training_selection_method: Sobol
# INFO:src.utils.logger:input_dim: 3
# INFO:src.utils.logger:hidden_dim: 50
# INFO:src.utils.logger:hidden_layers_dim: 3
# INFO:src.utils.logger:fluid_density: 1.0
# INFO:src.utils.logger:fluid_viscosity: 0.01
# INFO:src.utils.logger:num_epochs: 60000
# INFO:src.utils.logger:batch_size: 128
# INFO:src.utils.logger:learning_rate: 0.001
# INFO:src.utils.logger:data_weight: 2.0
# INFO:src.utils.logger:physics_weight: 0.01
# INFO:src.utils.logger:boundary_weight: 2.0
# INFO:src.utils.logger:fsi_weight: 0.5
# INFO:src.utils.logger:initial_weight: 4.0
# INFO:src.utils.logger:checkpoint_dir: ./checkpoints
# INFO:src.utils.logger:resume: None
# INFO:src.utils.logger:print_every: 100
# INFO:src.utils.logger:save_every: 200
# INFO:src.utils.logger:fluid_sampling_ratio: 0.01
# INFO:src.utils.logger:interface_sampling_ratio: 0.07
# INFO:src.utils.logger:solid_sampling_ratio: 0.0
# INFO:src.utils.logger:left_sampling_ratio: 0.1
# INFO:src.utils.logger:right_sampling_ratio: 0.15
# INFO:src.utils.logger:bottom_sampling_ratio: 0.1
# INFO:src.utils.logger:top_sampling_ratio: 0.1
# INFO:src.utils.logger:initial_sampling_ratio: 0.1
# INFO:src.utils.logger:device: cpu
# INFO:src.utils.logger:solver: mlp
# INFO:src.utils.logger:model: m1
# Loaded interface tensor from ./data/training_dataset/old/interface_tensor.pt with shape torch.Size([10166, 11])
# Loaded right tensor from ./data/training_dataset/old/right_tensor.pt with shape torch.Size([1545, 8])
# Loaded fluid_points tensor from ./data/training_dataset/old/fluid_points_tensor.pt with shape torch.Size([3986, 8])
# Loaded bottom tensor from ./data/training_dataset/old/bottom_tensor.pt with shape torch.Size([1030, 8])
# Loaded left tensor from ./data/training_dataset/old/left_tensor.pt with shape torch.Size([1030, 8])
# Loaded solid tensor from ./data/training_dataset/old/solid_tensor.pt with shape torch.Size([1452, 8])
# Loaded initial tensor from ./data/training_dataset/old/initial_tensor.pt with shape torch.Size([1330, 8])
# Loaded up tensor from ./data/training_dataset/old/up_tensor.pt with shape torch.Size([1030, 8])
# Loaded fluid tensor from ./data/training_dataset/old/fluid_tensor.pt with shape torch.Size([10508, 8])
# Loaded training dataset from ./data/training_dataset/old successfully!

# %%
visualize_tensor_datasets(training_data, save_dir=training_data_path)

fluid_network = (
    [config["input_dim"]] + [config["hidden_dim"]] * config["hidden_layers_dim"] + [3]
)
if config["solver"] == "mlp":
    fluid_model = MLP(network=fluid_network)
    solid_model = MLP(network=fluid_network)
else:
    fluid_model = KAN2(network=fluid_network)

logger.print("Fluid model architecture:")
logger.print(fluid_model)
logger.print(
    f"Number of parameters: {sum(p.numel() for p in fluid_model.parameters())}"
)
# Out:
# INFO:src.utils.logger:Fluid model architecture:
# INFO:src.utils.logger:MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=50, bias=True)
#     (1-2): 2 x Linear(in_features=50, out_features=50, bias=True)
#     (3): Linear(in_features=50, out_features=3, bias=True)
#   )
# )
# INFO:src.utils.logger:Number of parameters: 5453
# Saved tensor datasets scatter plot to ./data/training_dataset/old/tensor_datasets_scatter.png

# %%
trainer = PINNTrainer(
    fluid_model=fluid_model,
    solid_model=solid_model,
    training_data=training_data,
    learning_rate=config["learning_rate"],
    logger=logger,
    device=config["device"],
    fluid_density=config["fluid_density"],
    fluid_viscosity=config["fluid_viscosity"],
    print_every=config["print_every"],
    save_every=config["save_every"],
    solver=config["solver"],
    model=config["model"],
)


loss_history = trainer.train(
    num_epochs=config["num_epochs"],
    batch_size=config["batch_size"],
    data_weight=config["data_weight"],
    physics_weight=config["physics_weight"],
    boundary_weight=config["boundary_weight"],
    fsi_weight=config["fsi_weight"],
    initial_weight=config["initial_weight"],
)
# Out:
# INFO:src.utils.logger:Epoch 0/60000, Total: 6.1e+00, Data(F&S): 4.2e-01, Physics: 3.8e-03, Boundary: 4.8e+00, FSI: 5.1e-02, Solid: 6.6e-02, Initial: 7.3e-01, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 100/60000, Total: 2.1e+00, Data(F&S): 2.0e-01, Physics: 2.0e-03, Boundary: 1.7e+00, FSI: 1.3e-04, Solid: 7.5e-04, Initial: 1.3e-01, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.036e-01 |  Final right: 3.650e-01 |  Final bottom: 2.123e-02 |  Final up: 7.892e-01 |  Final fluid: 5.324e-03 |  Final interface: 1.110e-04 |  Final initial: 8.212e-02 |  Final fluid_total: 1.670e+00 |  Final solid_total: 7.425e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 200 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 200/60000, Total: 1.7e+00, Data(F&S): 2.0e-01, Physics: 5.4e-03, Boundary: 1.5e+00, FSI: 1.1e-04, Solid: 7.6e-04, Initial: 8.1e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 300/60000, Total: 1.2e+00, Data(F&S): 9.2e-02, Physics: 5.8e-03, Boundary: 1.0e+00, FSI: 5.8e-05, Solid: 5.6e-04, Initial: 9.1e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.335e-01 |  Final right: 2.271e-01 |  Final bottom: 4.266e-03 |  Final up: 4.534e-01 |  Final fluid: 7.408e-03 |  Final interface: 3.206e-05 |  Final initial: 7.439e-02 |  Final fluid_total: 9.719e-01 |  Final solid_total: 3.800e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 400 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 400/60000, Total: 9.8e-01, Data(F&S): 7.3e-02, Physics: 7.4e-03, Boundary: 8.3e-01, FSI: 3.1e-05, Solid: 3.7e-04, Initial: 7.6e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 500/60000, Total: 8.3e-01, Data(F&S): 6.0e-02, Physics: 1.1e-02, Boundary: 7.0e-01, FSI: 6.9e-05, Solid: 3.7e-04, Initial: 6.3e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 9.762e-02 |  Final right: 1.422e-01 |  Final bottom: 1.430e-03 |  Final up: 3.205e-01 |  Final fluid: 1.519e-02 |  Final interface: 4.072e-05 |  Final initial: 5.518e-02 |  Final fluid_total: 6.885e-01 |  Final solid_total: 4.027e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 600 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 600/60000, Total: 7.3e-01, Data(F&S): 5.6e-02, Physics: 1.5e-02, Boundary: 6.0e-01, FSI: 5.1e-05, Solid: 4.3e-04, Initial: 5.6e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 700/60000, Total: 6.2e-01, Data(F&S): 5.2e-02, Physics: 1.8e-02, Boundary: 5.0e-01, FSI: 5.7e-05, Solid: 4.2e-04, Initial: 4.9e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 7.523e-02 |  Final right: 9.744e-02 |  Final bottom: 1.232e-03 |  Final up: 2.942e-01 |  Final fluid: 2.033e-02 |  Final interface: 8.186e-05 |  Final initial: 4.112e-02 |  Final fluid_total: 5.784e-01 |  Final solid_total: 4.984e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 800 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 800/60000, Total: 5.5e-01, Data(F&S): 4.9e-02, Physics: 2.0e-02, Boundary: 4.5e-01, FSI: 6.9e-05, Solid: 4.6e-04, Initial: 4.0e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 900/60000, Total: 5.0e-01, Data(F&S): 4.7e-02, Physics: 2.4e-02, Boundary: 3.9e-01, FSI: 8.8e-05, Solid: 5.3e-04, Initial: 4.1e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 5.976e-02 |  Final right: 7.769e-02 |  Final bottom: 9.868e-04 |  Final up: 2.177e-01 |  Final fluid: 2.973e-02 |  Final interface: 6.473e-05 |  Final initial: 3.725e-02 |  Final fluid_total: 4.672e-01 |  Final solid_total: 5.093e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 1000 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 1000/60000, Total: 4.6e-01, Data(F&S): 4.4e-02, Physics: 3.0e-02, Boundary: 3.5e-01, FSI: 6.3e-05, Solid: 5.1e-04, Initial: 3.8e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1100/60000, Total: 4.2e-01, Data(F&S): 4.2e-02, Physics: 3.4e-02, Boundary: 3.1e-01, FSI: 8.7e-05, Solid: 4.9e-04, Initial: 3.6e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 5.139e-02 |  Final right: 4.553e-02 |  Final bottom: 1.305e-03 |  Final up: 1.812e-01 |  Final fluid: 3.812e-02 |  Final interface: 6.883e-05 |  Final initial: 3.233e-02 |  Final fluid_total: 3.898e-01 |  Final solid_total: 4.756e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 1200 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 1200/60000, Total: 3.9e-01, Data(F&S): 3.9e-02, Physics: 3.9e-02, Boundary: 2.8e-01, FSI: 7.3e-05, Solid: 4.8e-04, Initial: 3.3e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1300/60000, Total: 3.6e-01, Data(F&S): 3.9e-02, Physics: 3.9e-02, Boundary: 2.6e-01, FSI: 6.7e-05, Solid: 4.5e-04, Initial: 2.9e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 4.109e-02 |  Final right: 3.520e-02 |  Final bottom: 1.136e-03 |  Final up: 1.640e-01 |  Final fluid: 4.264e-02 |  Final interface: 4.800e-05 |  Final initial: 3.017e-02 |  Final fluid_total: 3.503e-01 |  Final solid_total: 3.978e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 1400 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 1400/60000, Total: 3.4e-01, Data(F&S): 3.6e-02, Physics: 4.1e-02, Boundary: 2.4e-01, FSI: 5.8e-05, Solid: 4.1e-04, Initial: 2.7e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1500/60000, Total: 3.4e-01, Data(F&S): 3.4e-02, Physics: 4.3e-02, Boundary: 2.4e-01, FSI: 5.8e-05, Solid: 4.0e-04, Initial: 2.7e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.694e-02 |  Final right: 2.907e-02 |  Final bottom: 7.893e-04 |  Final up: 1.622e-01 |  Final fluid: 4.408e-02 |  Final interface: 4.331e-05 |  Final initial: 2.684e-02 |  Final fluid_total: 3.340e-01 |  Final solid_total: 3.548e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 1600 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 1600/60000, Total: 3.5e-01, Data(F&S): 3.3e-02, Physics: 4.9e-02, Boundary: 2.4e-01, FSI: 3.9e-05, Solid: 3.5e-04, Initial: 2.9e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1700/60000, Total: 3.1e-01, Data(F&S): 3.2e-02, Physics: 4.8e-02, Boundary: 2.0e-01, FSI: 4.4e-05, Solid: 3.4e-04, Initial: 2.7e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 3.339e-02 |  Final right: 2.319e-02 |  Final bottom: 1.086e-03 |  Final up: 1.383e-01 |  Final fluid: 4.726e-02 |  Final interface: 3.323e-05 |  Final initial: 2.514e-02 |  Final fluid_total: 2.998e-01 |  Final solid_total: 2.956e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 1800 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 1800/60000, Total: 3.0e-01, Data(F&S): 3.1e-02, Physics: 4.6e-02, Boundary: 2.0e-01, FSI: 3.1e-05, Solid: 3.0e-04, Initial: 2.5e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 1900/60000, Total: 2.9e-01, Data(F&S): 3.1e-02, Physics: 5.0e-02, Boundary: 1.8e-01, FSI: 3.0e-05, Solid: 2.9e-04, Initial: 2.4e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.892e-02 |  Final right: 2.110e-02 |  Final bottom: 7.970e-04 |  Final up: 1.294e-01 |  Final fluid: 4.917e-02 |  Final interface: 3.563e-05 |  Final initial: 2.491e-02 |  Final fluid_total: 2.847e-01 |  Final solid_total: 2.784e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2000 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 2000/60000, Total: 2.7e-01, Data(F&S): 2.9e-02, Physics: 4.9e-02, Boundary: 1.7e-01, FSI: 4.5e-05, Solid: 2.9e-04, Initial: 2.4e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 2100/60000, Total: 2.8e-01, Data(F&S): 2.9e-02, Physics: 4.8e-02, Boundary: 1.8e-01, FSI: 3.6e-05, Solid: 3.0e-04, Initial: 2.4e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.692e-02 |  Final right: 1.832e-02 |  Final bottom: 8.318e-04 |  Final up: 1.178e-01 |  Final fluid: 4.899e-02 |  Final interface: 3.953e-05 |  Final initial: 2.095e-02 |  Final fluid_total: 2.631e-01 |  Final solid_total: 2.828e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2200 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 2200/60000, Total: 2.6e-01, Data(F&S): 2.9e-02, Physics: 4.8e-02, Boundary: 1.6e-01, FSI: 3.5e-05, Solid: 2.7e-04, Initial: 2.1e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 2300/60000, Total: 2.6e-01, Data(F&S): 2.9e-02, Physics: 4.5e-02, Boundary: 1.7e-01, FSI: 9.2e-05, Solid: 3.2e-04, Initial: 1.6e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.306e-02 |  Final right: 1.811e-02 |  Final bottom: 5.339e-04 |  Final up: 1.117e-01 |  Final fluid: 4.720e-02 |  Final interface: 4.604e-05 |  Final initial: 1.960e-02 |  Final fluid_total: 2.475e-01 |  Final solid_total: 2.815e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2400 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 2400/60000, Total: 2.5e-01, Data(F&S): 2.7e-02, Physics: 4.8e-02, Boundary: 1.6e-01, FSI: 4.2e-05, Solid: 2.8e-04, Initial: 2.1e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 2500/60000, Total: 2.4e-01, Data(F&S): 2.8e-02, Physics: 4.7e-02, Boundary: 1.5e-01, FSI: 4.3e-05, Solid: 2.8e-04, Initial: 1.9e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.414e-02 |  Final right: 1.677e-02 |  Final bottom: 5.103e-04 |  Final up: 1.200e-01 |  Final fluid: 5.071e-02 |  Final interface: 5.272e-05 |  Final initial: 1.872e-02 |  Final fluid_total: 2.572e-01 |  Final solid_total: 2.838e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2600 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 2600/60000, Total: 2.4e-01, Data(F&S): 2.6e-02, Physics: 5.1e-02, Boundary: 1.4e-01, FSI: 5.1e-05, Solid: 2.9e-04, Initial: 2.0e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 2700/60000, Total: 2.4e-01, Data(F&S): 2.6e-02, Physics: 4.6e-02, Boundary: 1.5e-01, FSI: 6.5e-05, Solid: 3.1e-04, Initial: 1.7e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 2.038e-02 |  Final right: 1.456e-02 |  Final bottom: 4.897e-04 |  Final up: 1.409e-01 |  Final fluid: 4.768e-02 |  Final interface: 5.314e-05 |  Final initial: 1.739e-02 |  Final fluid_total: 2.669e-01 |  Final solid_total: 2.920e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 2800 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 2800/60000, Total: 2.3e-01, Data(F&S): 2.6e-02, Physics: 4.6e-02, Boundary: 1.4e-01, FSI: 5.4e-05, Solid: 2.9e-04, Initial: 1.8e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 2900/60000, Total: 2.3e-01, Data(F&S): 2.5e-02, Physics: 4.8e-02, Boundary: 1.3e-01, FSI: 5.5e-05, Solid: 2.9e-04, Initial: 1.9e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.953e-02 |  Final right: 1.389e-02 |  Final bottom: 5.639e-04 |  Final up: 9.735e-02 |  Final fluid: 4.432e-02 |  Final interface: 6.044e-05 |  Final initial: 1.624e-02 |  Final fluid_total: 2.170e-01 |  Final solid_total: 3.018e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 3000 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 3000/60000, Total: 2.2e-01, Data(F&S): 2.5e-02, Physics: 4.5e-02, Boundary: 1.3e-01, FSI: 6.1e-05, Solid: 3.0e-04, Initial: 1.7e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 3100/60000, Total: 2.1e-01, Data(F&S): 2.5e-02, Physics: 4.5e-02, Boundary: 1.3e-01, FSI: 6.6e-05, Solid: 3.1e-04, Initial: 1.7e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.876e-02 |  Final right: 1.286e-02 |  Final bottom: 5.665e-04 |  Final up: 9.300e-02 |  Final fluid: 4.399e-02 |  Final interface: 6.532e-05 |  Final initial: 1.600e-02 |  Final fluid_total: 2.094e-01 |  Final solid_total: 3.099e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 3200 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 3200/60000, Total: 2.1e-01, Data(F&S): 2.4e-02, Physics: 4.3e-02, Boundary: 1.2e-01, FSI: 6.7e-05, Solid: 3.1e-04, Initial: 1.5e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 3300/60000, Total: 2.0e-01, Data(F&S): 2.4e-02, Physics: 4.2e-02, Boundary: 1.2e-01, FSI: 7.5e-05, Solid: 3.2e-04, Initial: 1.5e-02, LR: 1.00e-03
# INFO:src.utils.logger:Final losses:
# INFO:src.utils.logger:Final left: 1.747e-02 |  Final right: 1.235e-02 |  Final bottom: 5.258e-04 |  Final up: 1.275e-01 |  Final fluid: 4.253e-02 |  Final interface: 8.775e-05 |  Final initial: 1.754e-02 |  Final fluid_total: 2.420e-01 |  Final solid_total: 3.354e-04 |
# INFO:src.utils.logger:_save_checkpoint: Epoch 3400 | Training checkpoint saved at ./checkpoints/2025-08-17_22-11-00-832766/model.pth
# INFO:src.utils.logger:Epoch 3400/60000, Total: 2.0e-01, Data(F&S): 2.4e-02, Physics: 4.2e-02, Boundary: 1.2e-01, FSI: 7.6e-05, Solid: 3.2e-04, Initial: 1.6e-02, LR: 1.00e-03
# INFO:src.utils.logger:Epoch 3500/60000, Total: 2.0e-01, Data(F&S): 2.3e-02, Physics: 4.0e-02, Boundary: 1.2e-01, FSI: 8.5e-05, Solid: 3.4e-04, Initial: 1.5e-02, LR: 1.00e-03
